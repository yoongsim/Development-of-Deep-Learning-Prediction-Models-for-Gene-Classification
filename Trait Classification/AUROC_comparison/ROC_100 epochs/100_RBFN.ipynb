# %%
import numpy as np
import pandas as pd 

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler

from keras.models import Sequential
from keras.wrappers.scikit_learn import KerasClassifier
import matplotlib.pyplot as plt
import seaborn as sns

#for RBN
from keras.layers import Layer, Flatten, Dense, Lambda
from keras import backend as K
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from sklearn.metrics import ConfusionMatrixDisplay
from itertools import cycle
from keras import regularizers
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.utils import to_categorical

# %%
#fixed random seed for reproducibility 
np.random.seed(0)

# %%
# load dataset (input variables = X, output variables = Y)
df = pd.read_csv("TrainingData.csv")

dataTrait = df.drop(columns=["OsID", "Class"])# exclude OSID and Class Column
print("Summary of dataTrait:\n",dataTrait.describe())

X = dataTrait.drop(['Trait'], axis=1) # exclude log_2FoldChange and trait columns
Y = dataTrait['Trait']

print("Shape of X:\n",X.shape)
print("Shape of Y:\n",Y.shape)

# Statistical summary of the variables
print("Summary of X:\n",X.describe())
print("Summary of Y:\n",Y.describe())

# Check for class imbalance
print(df.groupby(Y).size())

# change both input and target variables datatype to ndarray
X = X.values # 2-D array

# select target variable 

Y = Y.values #1-D array
Y = Y.reshape(-1, 1)
# Out:
# Summary of dataTrait:
#         log_2FoldChange            ET  CoExpression           PCC
# count     41986.000000  41986.000000  41986.000000  41986.000000  \
# mean         -0.040210      1.386724      0.988687     -0.365709
# std           0.389447      0.796948      0.105762      0.462418
# min          -1.000000      0.000000      0.000000     -1.000000
# 25%          -0.251534      1.000000      1.000000     -0.750074
# 50%           0.030675      2.000000      1.000000     -0.449089
# 75%           0.251534      2.000000      1.000000     -0.055126
# max           1.000000      2.000000      1.000000      1.000000
#
#                 PPI  Root10DaysSeedling  Root14DaysSeedling
# count  41986.000000        41986.000000        41986.000000  \
# mean       0.909779           -0.526973           -0.646217
# std        0.286501            0.496871            0.393963
# min        0.000000           -1.000000           -1.000000
# 25%        1.000000           -0.906841           -0.965084
# 50%        1.000000           -0.663664           -0.680003
# 75%        1.000000           -0.378497           -0.559627
# max        1.000000            1.000000            1.000000
#
#        Root17DaysSeedling  Root21DaysSeedling  Root24DaysSeedling
# count        41986.000000        41986.000000        41986.000000  \
# mean            -0.700078           -0.668466           -0.668550
# std              0.379211            0.406829            0.392436
# min             -1.000000           -1.000000           -1.000000
# 25%             -0.980689           -1.000000           -0.982003
# 50%             -0.795609           -0.726665           -0.705842
# 75%             -0.601266           -0.543621           -0.485811
# max              1.000000            1.000000            1.000000
#
#        Root35DaysSeedling  Root52DaysSeedling  Shoot3DaysSeedling
# count        41986.000000        41986.000000        41986.000000  \
# mean            -0.596718           -0.669353           -0.589974
# std              0.461550            0.478191            0.445452
# min             -1.000000           -1.000000           -1.000000
# 25%             -0.937286           -1.000000           -1.000000
# 50%             -0.769184           -0.853382           -0.676286
# 75%             -0.323664           -0.537108           -0.410405
# max              1.000000            1.000000            1.000000
#
#        Shoot10DaysSeedling  Shoot14DaysSeedling  Shoot17DaysSeedling
# count         41986.000000         41986.000000         41986.000000  \
# mean             -0.545658            -0.732749            -0.680514
# std               0.476308             0.415345             0.478795
# min              -1.000000            -1.000000            -1.000000
# 25%              -0.906055            -1.000000            -1.000000
# 50%              -0.694063            -0.924976            -0.954040
# 75%              -0.262116            -0.513759            -0.420386
# max               1.000000             1.000000             1.000000
#
#        Shoot21DaysSeedling  Shoot35DaysSeedling  Leaf21DaysSeedling
# count         41986.000000         41986.000000        41986.000000  \
# mean             -0.658839            -0.559047           -0.826077
# std               0.464464             0.505545            0.331491
# min              -1.000000            -1.000000           -1.000000
# 25%              -1.000000            -0.962199           -1.000000
# 50%              -0.871560            -0.698696           -0.951894
# 75%              -0.440577            -0.352995           -0.869982
# max               1.000000             1.000000            1.000000
#
#        Leaf45DaysOldPlant
# count        41986.000000
# mean            -0.585725
# std              0.399673
# min             -1.000000
# 25%             -0.902160
# 50%             -0.643376
# 75%             -0.453136
# max              1.000000
# Shape of X:
#  (41986, 20)
# Shape of Y:
#  (41986,)
# Summary of X:
#         log_2FoldChange            ET  CoExpression           PCC
# count     41986.000000  41986.000000  41986.000000  41986.000000  \
# mean         -0.040210      1.386724      0.988687     -0.365709
# std           0.389447      0.796948      0.105762      0.462418
# min          -1.000000      0.000000      0.000000     -1.000000
# 25%          -0.251534      1.000000      1.000000     -0.750074
# 50%           0.030675      2.000000      1.000000     -0.449089
# 75%           0.251534      2.000000      1.000000     -0.055126
# max           1.000000      2.000000      1.000000      1.000000
#
#                 PPI  Root10DaysSeedling  Root14DaysSeedling
# count  41986.000000        41986.000000        41986.000000  \
# mean       0.909779           -0.526973           -0.646217
# std        0.286501            0.496871            0.393963
# min        0.000000           -1.000000           -1.000000
# 25%        1.000000           -0.906841           -0.965084
# 50%        1.000000           -0.663664           -0.680003
# 75%        1.000000           -0.378497           -0.559627
# max        1.000000            1.000000            1.000000
#
#        Root17DaysSeedling  Root21DaysSeedling  Root24DaysSeedling
# count        41986.000000        41986.000000        41986.000000  \
# mean            -0.700078           -0.668466           -0.668550
# std              0.379211            0.406829            0.392436
# min             -1.000000           -1.000000           -1.000000
# 25%             -0.980689           -1.000000           -0.982003
# 50%             -0.795609           -0.726665           -0.705842
# 75%             -0.601266           -0.543621           -0.485811
# max              1.000000            1.000000            1.000000
#
#        Root35DaysSeedling  Root52DaysSeedling  Shoot3DaysSeedling
# count        41986.000000        41986.000000        41986.000000  \
# mean            -0.596718           -0.669353           -0.589974
# std              0.461550            0.478191            0.445452
# min             -1.000000           -1.000000           -1.000000
# 25%             -0.937286           -1.000000           -1.000000
# 50%             -0.769184           -0.853382           -0.676286
# 75%             -0.323664           -0.537108           -0.410405
# max              1.000000            1.000000            1.000000
#
#        Shoot10DaysSeedling  Shoot14DaysSeedling  Shoot17DaysSeedling
# count         41986.000000         41986.000000         41986.000000  \
# mean             -0.545658            -0.732749            -0.680514
# std               0.476308             0.415345             0.478795
# min              -1.000000            -1.000000            -1.000000
# 25%              -0.906055            -1.000000            -1.000000
# 50%              -0.694063            -0.924976            -0.954040
# 75%              -0.262116            -0.513759            -0.420386
# max               1.000000             1.000000             1.000000
#
#        Shoot21DaysSeedling  Shoot35DaysSeedling  Leaf21DaysSeedling
# count         41986.000000         41986.000000        41986.000000  \
# mean             -0.658839            -0.559047           -0.826077
# std               0.464464             0.505545            0.331491
# min              -1.000000            -1.000000           -1.000000
# 25%              -1.000000            -0.962199           -1.000000
# 50%              -0.871560            -0.698696           -0.951894
# 75%              -0.440577            -0.352995           -0.869982
# max               1.000000             1.000000            1.000000
#
#        Leaf45DaysOldPlant
# count        41986.000000
# mean            -0.585725
# std              0.399673
# min             -1.000000
# 25%             -0.902160
# 50%             -0.643376
# 75%             -0.453136
# max              1.000000
# Summary of Y:
#  count       41986
# unique          6
# top       drought
# freq        13772
# Name: Trait, dtype: object
# Trait
# cold            5887
# drought        13772
# heat            8297
# salt            7662
# stress          6229
# submergence      139
# dtype: int64

# %%
class RBFLayer(Layer):
    def __init__(self, units, gamma, **kwargs):
        super(RBFLayer, self).__init__(**kwargs)
        self.units = units
        self.gamma = K.cast_to_floatx(gamma)

    def build(self, input_shape):
#         print(input_shape)
#         print(self.units)
        self.mu = self.add_weight(name='mu',
                                  shape=(int(input_shape[1]), self.units),
                                  initializer='uniform',
                                  trainable=True)
        super(RBFLayer, self).build(input_shape)

    def call(self, inputs):
        diff = K.expand_dims(inputs) - self.mu
        l2 = K.sum(K.pow(diff, 2), axis=1)
        res = K.exp(-1 * self.gamma * l2)
        return res

    def compute_output_shape(self, input_shape):
        return (input_shape[0], self.units)

# %%
# prepare target data
def prepare_targets(y_train, y_test):
	ohe = OneHotEncoder()
		
	y_train_enc = ohe.fit_transform(y_train)
	y_test_enc = ohe.transform(y_test)
	
	y_train_enc = y_train_enc.toarray()
	y_test_enc = y_test_enc.toarray()

	return y_train_enc, y_test_enc

# %%
# define baseline model (RBFN)
def RBFN_model():

    model = Sequential()
    model.add(Flatten(input_shape=(20,)))
    #add the RBF layer
    model.add(RBFLayer(10, 0.5))
    
    model.add(Dense(60, input_dim=20, activation='relu',bias_initializer='normal',kernel_regularizer=regularizers.l2(0.0001)))
    model.add(Dense(20,bias_initializer='normal',activation='relu',kernel_regularizer=regularizers.l2(0.0001)))
    model.add(Dense(20,bias_initializer='normal',activation='relu',kernel_regularizer=regularizers.l2(0.0001)))
    model.add(Dense(6,kernel_initializer='normal', activation='softmax')) #softmax for multi-class classification, num_classes = 6

    # Compile model
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %%
def accuracy(confusion_matrix):
   diagonal_sum = confusion_matrix.trace()
   sum_of_all_elements = confusion_matrix.sum()
   return diagonal_sum / sum_of_all_elements

# %%
def draw_confusion_matrix(cm):
    plt.figure(figsize=(12,8))
    sns.heatmap(cm,annot=True,fmt="d", center=0, cmap='autumn') 
    plt.title("Confusion Matrix")
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=1)

# prepare output data
y_train_enc, y_test_enc = prepare_targets(y_train, y_test)

# %%
# Define the number of folds for k-fold cross-validation
k = 2

# Define the cross-validation method
cv_method = StratifiedKFold(n_splits=k)

# Initialize the list to store the training, validation and test accuracy and loss of each fold
train_accuracy = []
train_loss = []
val_accuracy = []
val_loss = []
test_accuracy = []
models = []
hist = []

# Loop over the folds
for fold, (train_index, val_index) in enumerate(cv_method.split(X_train, y_train)):
    print("Fold:", fold+1)

    # Split the data into train and validation sets using the current fold index
    X_train_fold  = X_train[train_index]
    y_train_fold  = y_train[train_index]
    X_val_fold = X_train[val_index]
    y_val_fold = y_train[val_index]

    # Prepare the target data
    y_train_fold_enc, y_val_fold_enc = prepare_targets(y_train_fold, y_val_fold)

    # Build the model
    model = RBFN_model()

    # Fit the model to the training data for the current fold
    history = model.fit(X_train_fold,y_train_fold_enc, epochs=100, batch_size=5, verbose=1, validation_split = 0.33)
    
    # Evaluate the model on the validation data for the current fold
    val_scores = model.evaluate(X_val_fold, y_val_fold_enc, verbose=0)
    val_accuracy.append(val_scores[1])
    val_loss.append(val_scores[0])

    # Evaluate the model on the test data for the current fold
    test_scores = model.evaluate(X_test, y_test_enc, verbose=0)
    test_accuracy.append(test_scores[1])

    # add the model to the list of models
    models.append(model)
    hist.append(history)

    # store the training accuracy and loss for each fold
    train_accuracy.append(history.history['accuracy'])
    train_loss.append(history.history['loss'])
      
    # Print the test and validation accuracy and loss for the current fold
    print("Validation Accuracy:", val_scores[1])
    print("Validation Loss:", val_scores[0])
    print("Test Accuracy:", test_scores[1])
    print("Test Loss:", test_scores[0])

        
# Calculate the average test and validation accuracy and loss across all folds
avg_test_acc = sum(test_accuracy) / len(test_accuracy)
avg_val_acc = sum(val_accuracy) / len(val_accuracy)
avg_val_loss = sum(val_loss) / len(val_loss)

# Print the average validation and test accuracy and loss
print("Average Validation Accuracy:", avg_val_acc)
print("Average Validation Loss:",avg_val_loss)
print("Average Test Accuracy:", avg_test_acc)
# Out:
# Fold: 1
# Epoch 1/100
# 1885/1885 [==============================] - 9s 3ms/step - loss: 1.5859 - accuracy: 0.3262 - val_loss: 1.5622 - val_accuracy: 0.3283
# Epoch 2/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.5535 - accuracy: 0.3262 - val_loss: 1.5530 - val_accuracy: 0.3283
# Epoch 3/100
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.5485 - accuracy: 0.3262 - val_loss: 1.5492 - val_accuracy: 0.3283
# Epoch 4/100
# 1885/1885 [==============================] - 8s 4ms/step - loss: 1.5442 - accuracy: 0.3262 - val_loss: 1.5489 - val_accuracy: 0.3283
# Epoch 5/100
# 1885/1885 [==============================] - 8s 4ms/step - loss: 1.5426 - accuracy: 0.3262 - val_loss: 1.5448 - val_accuracy: 0.3283
# Epoch 6/100
# 1885/1885 [==============================] - 8s 4ms/step - loss: 1.5406 - accuracy: 0.3262 - val_loss: 1.5429 - val_accuracy: 0.3283
# Epoch 7/100
# 1885/1885 [==============================] - 8s 4ms/step - loss: 1.5370 - accuracy: 0.3262 - val_loss: 1.5388 - val_accuracy: 0.3283
# Epoch 8/100
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.5282 - accuracy: 0.3262 - val_loss: 1.5194 - val_accuracy: 0.3283
# Epoch 9/100
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.4706 - accuracy: 0.3541 - val_loss: 1.4376 - val_accuracy: 0.3858
# Epoch 10/100
# 1885/1885 [==============================] - 8s 4ms/step - loss: 1.4150 - accuracy: 0.3949 - val_loss: 1.4074 - val_accuracy: 0.4061
# Epoch 11/100
# 1885/1885 [==============================] - 8s 4ms/step - loss: 1.3866 - accuracy: 0.4101 - val_loss: 1.4073 - val_accuracy: 0.4050
# Epoch 12/100
# 1885/1885 [==============================] - 8s 4ms/step - loss: 1.3758 - accuracy: 0.4141 - val_loss: 1.3851 - val_accuracy: 0.4136
# Epoch 13/100
# 1885/1885 [==============================] - 8s 4ms/step - loss: 1.3679 - accuracy: 0.4142 - val_loss: 1.3846 - val_accuracy: 0.4112
# Epoch 14/100
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.3628 - accuracy: 0.4162 - val_loss: 1.3778 - val_accuracy: 0.4136
# Epoch 15/100
# 1885/1885 [==============================] - 8s 4ms/step - loss: 1.3576 - accuracy: 0.4164 - val_loss: 1.3738 - val_accuracy: 0.4149
# Epoch 16/100
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.3518 - accuracy: 0.4176 - val_loss: 1.3724 - val_accuracy: 0.4136
# Epoch 17/100
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.3486 - accuracy: 0.4182 - val_loss: 1.3661 - val_accuracy: 0.4162
# Epoch 18/100
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.3445 - accuracy: 0.4160 - val_loss: 1.3623 - val_accuracy: 0.4162
# Epoch 19/100
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.3385 - accuracy: 0.4197 - val_loss: 1.3629 - val_accuracy: 0.4194
# Epoch 20/100
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.3362 - accuracy: 0.4196 - val_loss: 1.3593 - val_accuracy: 0.4199
# Epoch 21/100
# 1885/1885 [==============================] - 7s 3ms/step - loss: 1.3332 - accuracy: 0.4217 - val_loss: 1.3567 - val_accuracy: 0.4222
# Epoch 22/100
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.3309 - accuracy: 0.4236 - val_loss: 1.3509 - val_accuracy: 0.4255
# Epoch 23/100
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.3275 - accuracy: 0.4302 - val_loss: 1.3493 - val_accuracy: 0.4339
# Epoch 24/100
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.3265 - accuracy: 0.4312 - val_loss: 1.3426 - val_accuracy: 0.4296
# Epoch 25/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.3239 - accuracy: 0.4310 - val_loss: 1.3497 - val_accuracy: 0.4229
# Epoch 26/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.3214 - accuracy: 0.4385 - val_loss: 1.3433 - val_accuracy: 0.4268
# Epoch 27/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.3195 - accuracy: 0.4321 - val_loss: 1.3410 - val_accuracy: 0.4308
# Epoch 28/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.3176 - accuracy: 0.4353 - val_loss: 1.3388 - val_accuracy: 0.4321
# Epoch 29/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.3154 - accuracy: 0.4360 - val_loss: 1.3360 - val_accuracy: 0.4358
# Epoch 30/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.3153 - accuracy: 0.4390 - val_loss: 1.3422 - val_accuracy: 0.4289
# Epoch 31/100
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.3113 - accuracy: 0.4375 - val_loss: 1.3303 - val_accuracy: 0.4349
# Epoch 32/100
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.3103 - accuracy: 0.4405 - val_loss: 1.3304 - val_accuracy: 0.4293
# Epoch 33/100
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.3091 - accuracy: 0.4397 - val_loss: 1.3278 - val_accuracy: 0.4360
# Epoch 34/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.3079 - accuracy: 0.4407 - val_loss: 1.3320 - val_accuracy: 0.4343
# Epoch 35/100
# 1885/1885 [==============================] - 8s 4ms/step - loss: 1.3073 - accuracy: 0.4378 - val_loss: 1.3522 - val_accuracy: 0.4227
# Epoch 36/100
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.3052 - accuracy: 0.4381 - val_loss: 1.3298 - val_accuracy: 0.4324
# Epoch 37/100
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.3047 - accuracy: 0.4394 - val_loss: 1.3251 - val_accuracy: 0.4339
# Epoch 38/100
# 1885/1885 [==============================] - 8s 4ms/step - loss: 1.3036 - accuracy: 0.4384 - val_loss: 1.3269 - val_accuracy: 0.4304
# Epoch 39/100
# 1885/1885 [==============================] - 8s 4ms/step - loss: 1.3021 - accuracy: 0.4392 - val_loss: 1.3306 - val_accuracy: 0.4280
# Epoch 40/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.3008 - accuracy: 0.4391 - val_loss: 1.3254 - val_accuracy: 0.4371
# Epoch 41/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.3000 - accuracy: 0.4418 - val_loss: 1.3275 - val_accuracy: 0.4291
# Epoch 42/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.2985 - accuracy: 0.4416 - val_loss: 1.3416 - val_accuracy: 0.4280
# Epoch 43/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.2980 - accuracy: 0.4421 - val_loss: 1.3182 - val_accuracy: 0.4364
# Epoch 44/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.2953 - accuracy: 0.4442 - val_loss: 1.3213 - val_accuracy: 0.4375
# Epoch 45/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.2949 - accuracy: 0.4404 - val_loss: 1.3154 - val_accuracy: 0.4377
# Epoch 46/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.2938 - accuracy: 0.4437 - val_loss: 1.3277 - val_accuracy: 0.4332
# Epoch 47/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.2933 - accuracy: 0.4424 - val_loss: 1.3236 - val_accuracy: 0.4403
# Epoch 48/100
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.2860 - accuracy: 0.4467 - val_loss: 1.3256 - val_accuracy: 0.4341
# Epoch 49/100
# 1885/1885 [==============================] - 8s 4ms/step - loss: 1.2821 - accuracy: 0.4509 - val_loss: 1.3090 - val_accuracy: 0.4433
# Epoch 50/100
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.2781 - accuracy: 0.4524 - val_loss: 1.3135 - val_accuracy: 0.4371
# Epoch 51/100
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.2758 - accuracy: 0.4492 - val_loss: 1.3041 - val_accuracy: 0.4545
# Epoch 52/100
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.2744 - accuracy: 0.4521 - val_loss: 1.3062 - val_accuracy: 0.4446
# Epoch 53/100
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.2705 - accuracy: 0.4530 - val_loss: 1.2924 - val_accuracy: 0.4541
# Epoch 54/100
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.2632 - accuracy: 0.4597 - val_loss: 1.3054 - val_accuracy: 0.4449
# Epoch 55/100
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.2578 - accuracy: 0.4631 - val_loss: 1.2878 - val_accuracy: 0.4634
# Epoch 56/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.2499 - accuracy: 0.4676 - val_loss: 1.2706 - val_accuracy: 0.4606
# Epoch 57/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.2416 - accuracy: 0.4664 - val_loss: 1.2724 - val_accuracy: 0.4601
# Epoch 58/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.2342 - accuracy: 0.4711 - val_loss: 1.2666 - val_accuracy: 0.4692
# Epoch 59/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.2287 - accuracy: 0.4721 - val_loss: 1.2574 - val_accuracy: 0.4748
# Epoch 60/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.2196 - accuracy: 0.4749 - val_loss: 1.2518 - val_accuracy: 0.4733
# Epoch 61/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.2112 - accuracy: 0.4779 - val_loss: 1.2467 - val_accuracy: 0.4688
# Epoch 62/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.2073 - accuracy: 0.4803 - val_loss: 1.2583 - val_accuracy: 0.4599
# Epoch 63/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1996 - accuracy: 0.4870 - val_loss: 1.2407 - val_accuracy: 0.4655
# Epoch 64/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1945 - accuracy: 0.4868 - val_loss: 1.2347 - val_accuracy: 0.4737
# Epoch 65/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1862 - accuracy: 0.4856 - val_loss: 1.2162 - val_accuracy: 0.4780
# Epoch 66/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1831 - accuracy: 0.4853 - val_loss: 1.2176 - val_accuracy: 0.4808
# Epoch 67/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.1787 - accuracy: 0.4884 - val_loss: 1.2162 - val_accuracy: 0.4810
# Epoch 68/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1749 - accuracy: 0.4880 - val_loss: 1.2111 - val_accuracy: 0.4692
# Epoch 69/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.1678 - accuracy: 0.4858 - val_loss: 1.1898 - val_accuracy: 0.4821
# Epoch 70/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.1599 - accuracy: 0.4891 - val_loss: 1.1804 - val_accuracy: 0.4813
# Epoch 71/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.1483 - accuracy: 0.4932 - val_loss: 1.1775 - val_accuracy: 0.4692
# Epoch 72/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.1433 - accuracy: 0.4911 - val_loss: 1.1683 - val_accuracy: 0.4879
# Epoch 73/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.1327 - accuracy: 0.4950 - val_loss: 1.1681 - val_accuracy: 0.4845
# Epoch 74/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1270 - accuracy: 0.4963 - val_loss: 1.1557 - val_accuracy: 0.4877
# Epoch 75/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1212 - accuracy: 0.4932 - val_loss: 1.1666 - val_accuracy: 0.4759
# Epoch 76/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1161 - accuracy: 0.4966 - val_loss: 1.1366 - val_accuracy: 0.4907
# Epoch 77/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1093 - accuracy: 0.4961 - val_loss: 1.1757 - val_accuracy: 0.4737
# Epoch 78/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1055 - accuracy: 0.4994 - val_loss: 1.1337 - val_accuracy: 0.4890
# Epoch 79/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.0999 - accuracy: 0.4996 - val_loss: 1.1551 - val_accuracy: 0.4841
# Epoch 80/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.0964 - accuracy: 0.5030 - val_loss: 1.1134 - val_accuracy: 0.4871
# Epoch 81/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.0904 - accuracy: 0.5001 - val_loss: 1.1077 - val_accuracy: 0.4961
# Epoch 82/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.0857 - accuracy: 0.4995 - val_loss: 1.1557 - val_accuracy: 0.4731
# Epoch 83/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.0801 - accuracy: 0.5090 - val_loss: 1.1134 - val_accuracy: 0.5017
# Epoch 84/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.0725 - accuracy: 0.5109 - val_loss: 1.0965 - val_accuracy: 0.4989
# Epoch 85/100
# 1885/1885 [==============================] - 8s 4ms/step - loss: 1.0712 - accuracy: 0.5114 - val_loss: 1.0949 - val_accuracy: 0.5065
# Epoch 86/100
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.0690 - accuracy: 0.5144 - val_loss: 1.0981 - val_accuracy: 0.4994
# Epoch 87/100
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.0619 - accuracy: 0.5105 - val_loss: 1.0941 - val_accuracy: 0.5103
# Epoch 88/100
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.0582 - accuracy: 0.5150 - val_loss: 1.0737 - val_accuracy: 0.5140
# Epoch 89/100
# 1885/1885 [==============================] - 8s 4ms/step - loss: 1.0572 - accuracy: 0.5131 - val_loss: 1.0908 - val_accuracy: 0.5082
# Epoch 90/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.0551 - accuracy: 0.5164 - val_loss: 1.0759 - val_accuracy: 0.5078
# Epoch 91/100
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.0527 - accuracy: 0.5148 - val_loss: 1.0748 - val_accuracy: 0.5192
# Epoch 92/100
# 1885/1885 [==============================] - 8s 4ms/step - loss: 1.0482 - accuracy: 0.5209 - val_loss: 1.0810 - val_accuracy: 0.5134
# Epoch 93/100
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.0438 - accuracy: 0.5205 - val_loss: 1.0903 - val_accuracy: 0.5052
# Epoch 94/100
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.0442 - accuracy: 0.5186 - val_loss: 1.0823 - val_accuracy: 0.5125
# Epoch 95/100
# 1885/1885 [==============================] - 8s 4ms/step - loss: 1.0393 - accuracy: 0.5183 - val_loss: 1.0609 - val_accuracy: 0.5183
# Epoch 96/100
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.0368 - accuracy: 0.5214 - val_loss: 1.0637 - val_accuracy: 0.5123
# Epoch 97/100
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.0367 - accuracy: 0.5160 - val_loss: 1.0797 - val_accuracy: 0.5071
# Epoch 98/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.0319 - accuracy: 0.5261 - val_loss: 1.0922 - val_accuracy: 0.5082
# Epoch 99/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.0283 - accuracy: 0.5245 - val_loss: 1.0739 - val_accuracy: 0.5138
# Epoch 100/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.0263 - accuracy: 0.5294 - val_loss: 1.0855 - val_accuracy: 0.5039
# Validation Accuracy: 0.5092783570289612
# Validation Loss: 1.0775495767593384
# Test Accuracy: 0.517320990562439
# Test Loss: 1.0648771524429321
# Fold: 2
# Epoch 1/100
# 1885/1885 [==============================] - 8s 3ms/step - loss: 1.5909 - accuracy: 0.3207 - val_loss: 1.5494 - val_accuracy: 0.3376
# Epoch 2/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.5562 - accuracy: 0.3218 - val_loss: 1.5377 - val_accuracy: 0.3376
# Epoch 3/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.5488 - accuracy: 0.3218 - val_loss: 1.5364 - val_accuracy: 0.3376
# Epoch 4/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.5444 - accuracy: 0.3218 - val_loss: 1.5312 - val_accuracy: 0.3376
# Epoch 5/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.5399 - accuracy: 0.3218 - val_loss: 1.5358 - val_accuracy: 0.3376
# Epoch 6/100
# 1885/1885 [==============================] - 8s 4ms/step - loss: 1.5362 - accuracy: 0.3218 - val_loss: 1.5255 - val_accuracy: 0.3376
# Epoch 7/100
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.5338 - accuracy: 0.3218 - val_loss: 1.5261 - val_accuracy: 0.3376
# Epoch 8/100
# 1885/1885 [==============================] - 7s 3ms/step - loss: 1.5319 - accuracy: 0.3218 - val_loss: 1.5218 - val_accuracy: 0.3376
# Epoch 9/100
# 1885/1885 [==============================] - 8s 4ms/step - loss: 1.5302 - accuracy: 0.3218 - val_loss: 1.5231 - val_accuracy: 0.3376
# Epoch 10/100
# 1885/1885 [==============================] - 7s 3ms/step - loss: 1.5277 - accuracy: 0.3218 - val_loss: 1.5216 - val_accuracy: 0.3376
# Epoch 11/100
# 1885/1885 [==============================] - 10s 5ms/step - loss: 1.5247 - accuracy: 0.3218 - val_loss: 1.5141 - val_accuracy: 0.3376
# Epoch 12/100
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.5218 - accuracy: 0.3218 - val_loss: 1.5180 - val_accuracy: 0.3376
# Epoch 13/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.5182 - accuracy: 0.3218 - val_loss: 1.5053 - val_accuracy: 0.3376
# Epoch 14/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.5137 - accuracy: 0.3219 - val_loss: 1.5030 - val_accuracy: 0.3376
# Epoch 15/100
# 1885/1885 [==============================] - 8s 4ms/step - loss: 1.5079 - accuracy: 0.3217 - val_loss: 1.4964 - val_accuracy: 0.3302
# Epoch 16/100
# 1885/1885 [==============================] - 10s 5ms/step - loss: 1.4889 - accuracy: 0.3353 - val_loss: 1.4587 - val_accuracy: 0.3813
# Epoch 17/100
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.4169 - accuracy: 0.3899 - val_loss: 1.3888 - val_accuracy: 0.4052
# Epoch 18/100
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.3772 - accuracy: 0.4023 - val_loss: 1.3635 - val_accuracy: 0.4104
# Epoch 19/100
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.3580 - accuracy: 0.4068 - val_loss: 1.3550 - val_accuracy: 0.4121
# Epoch 20/100
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.3471 - accuracy: 0.4092 - val_loss: 1.3506 - val_accuracy: 0.4115
# Epoch 21/100
# 1885/1885 [==============================] - 8s 4ms/step - loss: 1.3402 - accuracy: 0.4101 - val_loss: 1.3457 - val_accuracy: 0.4199
# Epoch 22/100
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.3309 - accuracy: 0.4181 - val_loss: 1.3347 - val_accuracy: 0.4143
# Epoch 23/100
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.3199 - accuracy: 0.4234 - val_loss: 1.3243 - val_accuracy: 0.4233
# Epoch 24/100
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.3099 - accuracy: 0.4277 - val_loss: 1.3183 - val_accuracy: 0.4384
# Epoch 25/100
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.2989 - accuracy: 0.4386 - val_loss: 1.3179 - val_accuracy: 0.4446
# Epoch 26/100
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.2871 - accuracy: 0.4487 - val_loss: 1.3115 - val_accuracy: 0.4507
# Epoch 27/100
# 1885/1885 [==============================] - 8s 4ms/step - loss: 1.2789 - accuracy: 0.4588 - val_loss: 1.2892 - val_accuracy: 0.4591
# Epoch 28/100
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.2709 - accuracy: 0.4616 - val_loss: 1.2938 - val_accuracy: 0.4388
# Epoch 29/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.2621 - accuracy: 0.4665 - val_loss: 1.2809 - val_accuracy: 0.4591
# Epoch 30/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.2568 - accuracy: 0.4692 - val_loss: 1.2712 - val_accuracy: 0.4668
# Epoch 31/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.2518 - accuracy: 0.4731 - val_loss: 1.2637 - val_accuracy: 0.4754
# Epoch 32/100
# 1885/1885 [==============================] - 7s 3ms/step - loss: 1.2473 - accuracy: 0.4755 - val_loss: 1.2815 - val_accuracy: 0.4502
# Epoch 33/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.2436 - accuracy: 0.4749 - val_loss: 1.2614 - val_accuracy: 0.4681
# Epoch 34/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.2407 - accuracy: 0.4768 - val_loss: 1.2648 - val_accuracy: 0.4681
# Epoch 35/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.2393 - accuracy: 0.4768 - val_loss: 1.2613 - val_accuracy: 0.4673
# Epoch 36/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.2354 - accuracy: 0.4800 - val_loss: 1.2524 - val_accuracy: 0.4793
# Epoch 37/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.2322 - accuracy: 0.4795 - val_loss: 1.2517 - val_accuracy: 0.4752
# Epoch 38/100
# 1885/1885 [==============================] - 7s 3ms/step - loss: 1.2286 - accuracy: 0.4797 - val_loss: 1.2523 - val_accuracy: 0.4724
# Epoch 39/100
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.2292 - accuracy: 0.4791 - val_loss: 1.2399 - val_accuracy: 0.4778
# Epoch 40/100
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.2241 - accuracy: 0.4795 - val_loss: 1.2439 - val_accuracy: 0.4754
# Epoch 41/100
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.2236 - accuracy: 0.4811 - val_loss: 1.2518 - val_accuracy: 0.4737
# Epoch 42/100
# 1885/1885 [==============================] - 8s 4ms/step - loss: 1.2216 - accuracy: 0.4834 - val_loss: 1.2431 - val_accuracy: 0.4724
# Epoch 43/100
# 1885/1885 [==============================] - 8s 4ms/step - loss: 1.2166 - accuracy: 0.4822 - val_loss: 1.2437 - val_accuracy: 0.4757
# Epoch 44/100
# 1885/1885 [==============================] - 7s 3ms/step - loss: 1.2146 - accuracy: 0.4843 - val_loss: 1.2421 - val_accuracy: 0.4632
# Epoch 45/100
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.2134 - accuracy: 0.4833 - val_loss: 1.2286 - val_accuracy: 0.4735
# Epoch 46/100
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.2140 - accuracy: 0.4791 - val_loss: 1.2262 - val_accuracy: 0.4815
# Epoch 47/100
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.2100 - accuracy: 0.4807 - val_loss: 1.2311 - val_accuracy: 0.4769
# Epoch 48/100
# 1885/1885 [==============================] - 8s 4ms/step - loss: 1.2096 - accuracy: 0.4849 - val_loss: 1.2258 - val_accuracy: 0.4718
# Epoch 49/100
# 1885/1885 [==============================] - 8s 4ms/step - loss: 1.2095 - accuracy: 0.4811 - val_loss: 1.2348 - val_accuracy: 0.4744
# Epoch 50/100
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.2066 - accuracy: 0.4859 - val_loss: 1.2196 - val_accuracy: 0.4821
# Epoch 51/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.2059 - accuracy: 0.4873 - val_loss: 1.2236 - val_accuracy: 0.4806
# Epoch 52/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.2038 - accuracy: 0.4890 - val_loss: 1.2408 - val_accuracy: 0.4759
# Epoch 53/100
# 1885/1885 [==============================] - 7s 3ms/step - loss: 1.2026 - accuracy: 0.4890 - val_loss: 1.2178 - val_accuracy: 0.4826
# Epoch 54/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1996 - accuracy: 0.4905 - val_loss: 1.2298 - val_accuracy: 0.4754
# Epoch 55/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.2021 - accuracy: 0.4855 - val_loss: 1.2565 - val_accuracy: 0.4711
# Epoch 56/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1997 - accuracy: 0.4922 - val_loss: 1.2113 - val_accuracy: 0.4806
# Epoch 57/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1967 - accuracy: 0.4868 - val_loss: 1.2143 - val_accuracy: 0.4834
# Epoch 58/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1967 - accuracy: 0.4941 - val_loss: 1.2151 - val_accuracy: 0.4879
# Epoch 59/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1929 - accuracy: 0.4936 - val_loss: 1.2125 - val_accuracy: 0.4836
# Epoch 60/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1953 - accuracy: 0.4902 - val_loss: 1.2143 - val_accuracy: 0.4765
# Epoch 61/100
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.1929 - accuracy: 0.4908 - val_loss: 1.2109 - val_accuracy: 0.4838
# Epoch 62/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1895 - accuracy: 0.4966 - val_loss: 1.2137 - val_accuracy: 0.4871
# Epoch 63/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1904 - accuracy: 0.4978 - val_loss: 1.2111 - val_accuracy: 0.4858
# Epoch 64/100
# 1885/1885 [==============================] - 7s 3ms/step - loss: 1.1854 - accuracy: 0.4950 - val_loss: 1.2037 - val_accuracy: 0.4873
# Epoch 65/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1847 - accuracy: 0.4956 - val_loss: 1.2105 - val_accuracy: 0.4817
# Epoch 66/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1822 - accuracy: 0.4937 - val_loss: 1.1977 - val_accuracy: 0.4888
# Epoch 67/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1791 - accuracy: 0.4972 - val_loss: 1.2053 - val_accuracy: 0.4869
# Epoch 68/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1786 - accuracy: 0.4973 - val_loss: 1.2004 - val_accuracy: 0.4933
# Epoch 69/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1748 - accuracy: 0.5002 - val_loss: 1.2031 - val_accuracy: 0.4845
# Epoch 70/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1726 - accuracy: 0.4974 - val_loss: 1.2094 - val_accuracy: 0.4843
# Epoch 71/100
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.1660 - accuracy: 0.5015 - val_loss: 1.1941 - val_accuracy: 0.4860
# Epoch 72/100
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.1653 - accuracy: 0.4951 - val_loss: 1.1946 - val_accuracy: 0.4832
# Epoch 73/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1598 - accuracy: 0.5003 - val_loss: 1.1761 - val_accuracy: 0.4866
# Epoch 74/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1565 - accuracy: 0.4980 - val_loss: 1.1742 - val_accuracy: 0.4845
# Epoch 75/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1538 - accuracy: 0.4968 - val_loss: 1.1778 - val_accuracy: 0.4916
# Epoch 76/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1499 - accuracy: 0.4999 - val_loss: 1.1787 - val_accuracy: 0.4795
# Epoch 77/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1479 - accuracy: 0.5007 - val_loss: 1.1843 - val_accuracy: 0.4882
# Epoch 78/100
# 1885/1885 [==============================] - 7s 3ms/step - loss: 1.1470 - accuracy: 0.4928 - val_loss: 1.1646 - val_accuracy: 0.4899
# Epoch 79/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1425 - accuracy: 0.4982 - val_loss: 1.1701 - val_accuracy: 0.4918
# Epoch 80/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1387 - accuracy: 0.5027 - val_loss: 1.1618 - val_accuracy: 0.4955
# Epoch 81/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1369 - accuracy: 0.5003 - val_loss: 1.1703 - val_accuracy: 0.4935
# Epoch 82/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1334 - accuracy: 0.4987 - val_loss: 1.1499 - val_accuracy: 0.4974
# Epoch 83/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1311 - accuracy: 0.4987 - val_loss: 1.1623 - val_accuracy: 0.4929
# Epoch 84/100
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.1299 - accuracy: 0.5056 - val_loss: 1.1467 - val_accuracy: 0.4772
# Epoch 85/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.1262 - accuracy: 0.5013 - val_loss: 1.1476 - val_accuracy: 0.4933
# Epoch 86/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.1247 - accuracy: 0.5060 - val_loss: 1.1655 - val_accuracy: 0.4832
# Epoch 87/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.1239 - accuracy: 0.5024 - val_loss: 1.1483 - val_accuracy: 0.4884
# Epoch 88/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.1210 - accuracy: 0.5012 - val_loss: 1.1374 - val_accuracy: 0.4961
# Epoch 89/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.1200 - accuracy: 0.5023 - val_loss: 1.1431 - val_accuracy: 0.4968
# Epoch 90/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.1213 - accuracy: 0.5005 - val_loss: 1.1411 - val_accuracy: 0.4862
# Epoch 91/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.1139 - accuracy: 0.5031 - val_loss: 1.1345 - val_accuracy: 0.4877
# Epoch 92/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.1156 - accuracy: 0.4995 - val_loss: 1.1362 - val_accuracy: 0.4879
# Epoch 93/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.1094 - accuracy: 0.5041 - val_loss: 1.1263 - val_accuracy: 0.4907
# Epoch 94/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.1099 - accuracy: 0.5034 - val_loss: 1.1329 - val_accuracy: 0.4907
# Epoch 95/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.1036 - accuracy: 0.5124 - val_loss: 1.1166 - val_accuracy: 0.4942
# Epoch 96/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.1044 - accuracy: 0.5036 - val_loss: 1.1504 - val_accuracy: 0.4933
# Epoch 97/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.0992 - accuracy: 0.5068 - val_loss: 1.1293 - val_accuracy: 0.4961
# Epoch 98/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.0967 - accuracy: 0.5082 - val_loss: 1.1307 - val_accuracy: 0.4989
# Epoch 99/100
# 1885/1885 [==============================] - 5s 3ms/step - loss: 1.0942 - accuracy: 0.5090 - val_loss: 1.1272 - val_accuracy: 0.4823
# Epoch 100/100
# 1885/1885 [==============================] - 5s 2ms/step - loss: 1.0939 - accuracy: 0.5054 - val_loss: 1.1036 - val_accuracy: 0.4970
# Validation Accuracy: 0.5030927658081055
# Validation Loss: 1.1025978326797485
# Test Accuracy: 0.5055571794509888
# Test Loss: 1.0991270542144775
# Average Validation Accuracy: 0.5061855614185333
# Average Validation Loss: 1.0900737047195435
# Average Test Accuracy: 0.5114390850067139

# %%
# Select the final model based on the average test accuracy across all folds
best_model_index = test_accuracy.index(max(test_accuracy))
best_model = models[best_model_index]
best_model_history = hist[best_model_index]
best_model_train_acc = train_accuracy[best_model_index]
best_model_train_loss = train_loss[best_model_index]
best_model_val_acc = val_accuracy[best_model_index]
best_model_val_loss = val_loss[best_model_index]

# summarize history for accuracy  
plt.subplot(211)  
plt.plot(best_model_history.history['accuracy'])  
plt.plot(best_model_history.history['val_accuracy'])  
plt.title('model accuracy')  
plt.ylabel('accuracy')  
plt.xlabel('epoch')  
plt.legend(['train', 'validation'], loc='lower right')  

# summarize history for loss
plt.subplot(212)  
plt.plot(best_model_history.history['loss'])  
plt.plot(best_model_history.history['val_loss'])  
plt.title('model loss')  
plt.ylabel('loss')  
plt.xlabel('epoch')  
plt.legend(['train', 'validation'], loc='upper right')  


plt.subplots_adjust(hspace=0.7)

plt.show() 

print("Final Test Accuracy:", test_accuracy[best_model_index])
# Out:
# Final Test Accuracy: 0.517320990562439

# %%
# Evaluate the best model on the test data
y_pred = best_model.predict(X_test)

# np.argmax() is used to convert the one-hot encoded predictions and test labels to class labels.
y_pred_label=np.argmax(y_pred, axis = 1)


rounded_ytestenc=np.argmax(y_test_enc, axis=1)

# Print the classification report
print("Classification report:\n", classification_report(rounded_ytestenc, y_pred_label))

cm = confusion_matrix(rounded_ytestenc, y_pred_label)
draw_confusion_matrix(cm)
print("Confusion matrix:\n", cm)

#Printing the accuracy
print(accuracy(cm))
# Out:
# 433/433 [==============================] - 1s 2ms/step
# c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.39      0.49      0.43      1909
#            1       0.48      0.61      0.54      4575
#            2       0.83      0.65      0.73      2787
#            3       0.42      0.16      0.24      2469
#            4       0.49      0.60      0.54      2066
#            5       0.00      0.00      0.00        50
#
#     accuracy                           0.52     13856
#    macro avg       0.43      0.42      0.41     13856
# weighted avg       0.53      0.52      0.51     13856
# Confusion matrix:
#  [[ 927  624   49  110  199    0]
#  [ 795 2793  262  244  481    0]
#  [  56  849 1803    0   79    0]
#  [ 454 1047   46  405  517    0]
#  [ 146  453   18  209 1240    0]
#  [  16   18    1    0   15    0]]
# 0.5173210161662818

# %%
target_names = np.array(['cold', 'drought', 'heat', 'salt', 'stress', 'submergence'])

n_classes = len(np.unique(Y)) # 6

# predict probabilities for each class
y_score = best_model.predict(X_test)


# store the fpr, tpr, and roc_auc for all averaging strategies
fpr, tpr, roc_auc = dict(), dict(), dict()

# ROC curve using micro-averaged OvR
# Compute micro-average ROC curve and ROC area
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_enc[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test_enc.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Compute macro-average ROC curve and ROC area
# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at these points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

#Plot all OvR ROC curves together
fig, ax = plt.subplots(figsize=(8, 6))

colors = cycle(["aqua", "darkorange", "cornflowerblue", "green", "purple", "red"])
for class_id, color, target_name in zip(range(n_classes), colors, target_names):
    plt.plot(
        fpr[class_id],
        tpr[class_id],
        color=color,
        lw=2,
        label=f"{target_name} (AUC = {roc_auc[class_id]:.3f})",
    )

plt.plot(
    fpr["micro"],
    tpr["micro"],
    label=f"micro-average (AUC = {roc_auc['micro']:.3f})",
    color="deeppink",
    linestyle=":",
    linewidth=4,
)

plt.plot(
    fpr["macro"],
    tpr["macro"],
    label=f"macro-average (AUC = {roc_auc['macro']:.3f})",
    color="navy",
    linestyle=":",
    linewidth=4,
)



plt.plot([0, 1], [0, 1], "k--", label="chance level (AUC = 0.5)")
plt.axis("square")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("One-vs-Rest multiclass ROC")
plt.legend(loc="lower right")
plt.show()
# Out:
# 433/433 [==============================] - 1s 1ms/step

# %%
import pickle

filepath = 'RBFN_roc.pkl'
data = {'RBFN_fpr_macro': fpr['macro'],
        'RBFN_tpr_macro': tpr['macro'],
        'RBFN_auc_macro': roc_auc['macro']}

with open(filepath,'wb') as f:
    pickle.dump(data,f)

# %%
#created for the result.csv
dataTrait1 = df.drop(columns=["Class"]) #create for csv output
X1 = dataTrait1.drop(["Trait"], axis=1) #create for csv output

# split into train and test sets
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, Y, test_size=0.33, random_state=1)

# extract OsID from test data 
OsID_test = X_test1['OsID'].values

trait_names = (['cold', 'drought', 'heat', 'salt', 'stress', 'submergence'])

# map class labels to target names
true_class = [trait_names[i] for i in rounded_ytestenc]
predicted_class = [trait_names[i] for i in y_pred_label]

# create dataframe with OsID, true class, predicted class, and true/false columns
results = pd.DataFrame({
    'OsID': OsID_test,
    'True Class': true_class,
    'Predicted Class': predicted_class,
    'True/False': [x == y for x, y in zip(true_class, predicted_class)]})


# display dataframe
print(results.head())

# save results_df to a CSV file
results.to_csv('RBFN_trait classification.csv', index=False)
# Out:
#            OsID True Class Predicted Class  True/False
# 0  Os09g0522200       cold            salt       False
# 1  Os11g0592200    drought         drought        True
# 2  Os01g0699100     stress          stress        True
# 3  Os02g0126400    drought         drought        True
# 4  Os03g0669100    drought          stress       False
