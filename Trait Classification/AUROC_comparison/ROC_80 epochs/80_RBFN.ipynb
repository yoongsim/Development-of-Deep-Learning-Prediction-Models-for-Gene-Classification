# %%
import numpy as np
import pandas as pd 

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler

from keras.models import Sequential
from keras.wrappers.scikit_learn import KerasClassifier
import matplotlib.pyplot as plt
import seaborn as sns

#for RBN
from keras.layers import Layer, Flatten, Dense, Lambda
from keras import backend as K
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from sklearn.metrics import ConfusionMatrixDisplay
from itertools import cycle
from keras import regularizers
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.utils import to_categorical

# %%
#fixed random seed for reproducibility 
np.random.seed(0)

# %%
# load dataset (input variables = X, output variables = Y)
df = pd.read_csv("TrainingData.csv")

dataTrait = df.drop(columns=["OsID", "Class"])# exclude OSID and Class Column
print("Summary of dataTrait:\n",dataTrait.describe())

X = dataTrait.drop(['Trait'], axis=1) # exclude log_2FoldChange and trait columns
Y = dataTrait['Trait']

print("Shape of X:\n",X.shape)
print("Shape of Y:\n",Y.shape)

# Statistical summary of the variables
print("Summary of X:\n",X.describe())
print("Summary of Y:\n",Y.describe())

# Check for class imbalance
print(df.groupby(Y).size())

# change both input and target variables datatype to ndarray
X = X.values # 2-D array

# select target variable 

Y = Y.values #1-D array
Y = Y.reshape(-1, 1)
# Out:
# Summary of dataTrait:
#         log_2FoldChange            ET  CoExpression           PCC
# count     41986.000000  41986.000000  41986.000000  41986.000000  \
# mean         -0.040210      1.386724      0.988687     -0.365709
# std           0.389447      0.796948      0.105762      0.462418
# min          -1.000000      0.000000      0.000000     -1.000000
# 25%          -0.251534      1.000000      1.000000     -0.750074
# 50%           0.030675      2.000000      1.000000     -0.449089
# 75%           0.251534      2.000000      1.000000     -0.055126
# max           1.000000      2.000000      1.000000      1.000000
#
#                 PPI  Root10DaysSeedling  Root14DaysSeedling
# count  41986.000000        41986.000000        41986.000000  \
# mean       0.909779           -0.526973           -0.646217
# std        0.286501            0.496871            0.393963
# min        0.000000           -1.000000           -1.000000
# 25%        1.000000           -0.906841           -0.965084
# 50%        1.000000           -0.663664           -0.680003
# 75%        1.000000           -0.378497           -0.559627
# max        1.000000            1.000000            1.000000
#
#        Root17DaysSeedling  Root21DaysSeedling  Root24DaysSeedling
# count        41986.000000        41986.000000        41986.000000  \
# mean            -0.700078           -0.668466           -0.668550
# std              0.379211            0.406829            0.392436
# min             -1.000000           -1.000000           -1.000000
# 25%             -0.980689           -1.000000           -0.982003
# 50%             -0.795609           -0.726665           -0.705842
# 75%             -0.601266           -0.543621           -0.485811
# max              1.000000            1.000000            1.000000
#
#        Root35DaysSeedling  Root52DaysSeedling  Shoot3DaysSeedling
# count        41986.000000        41986.000000        41986.000000  \
# mean            -0.596718           -0.669353           -0.589974
# std              0.461550            0.478191            0.445452
# min             -1.000000           -1.000000           -1.000000
# 25%             -0.937286           -1.000000           -1.000000
# 50%             -0.769184           -0.853382           -0.676286
# 75%             -0.323664           -0.537108           -0.410405
# max              1.000000            1.000000            1.000000
#
#        Shoot10DaysSeedling  Shoot14DaysSeedling  Shoot17DaysSeedling
# count         41986.000000         41986.000000         41986.000000  \
# mean             -0.545658            -0.732749            -0.680514
# std               0.476308             0.415345             0.478795
# min              -1.000000            -1.000000            -1.000000
# 25%              -0.906055            -1.000000            -1.000000
# 50%              -0.694063            -0.924976            -0.954040
# 75%              -0.262116            -0.513759            -0.420386
# max               1.000000             1.000000             1.000000
#
#        Shoot21DaysSeedling  Shoot35DaysSeedling  Leaf21DaysSeedling
# count         41986.000000         41986.000000        41986.000000  \
# mean             -0.658839            -0.559047           -0.826077
# std               0.464464             0.505545            0.331491
# min              -1.000000            -1.000000           -1.000000
# 25%              -1.000000            -0.962199           -1.000000
# 50%              -0.871560            -0.698696           -0.951894
# 75%              -0.440577            -0.352995           -0.869982
# max               1.000000             1.000000            1.000000
#
#        Leaf45DaysOldPlant
# count        41986.000000
# mean            -0.585725
# std              0.399673
# min             -1.000000
# 25%             -0.902160
# 50%             -0.643376
# 75%             -0.453136
# max              1.000000
# Shape of X:
#  (41986, 20)
# Shape of Y:
#  (41986,)
# Summary of X:
#         log_2FoldChange            ET  CoExpression           PCC
# count     41986.000000  41986.000000  41986.000000  41986.000000  \
# mean         -0.040210      1.386724      0.988687     -0.365709
# std           0.389447      0.796948      0.105762      0.462418
# min          -1.000000      0.000000      0.000000     -1.000000
# 25%          -0.251534      1.000000      1.000000     -0.750074
# 50%           0.030675      2.000000      1.000000     -0.449089
# 75%           0.251534      2.000000      1.000000     -0.055126
# max           1.000000      2.000000      1.000000      1.000000
#
#                 PPI  Root10DaysSeedling  Root14DaysSeedling
# count  41986.000000        41986.000000        41986.000000  \
# mean       0.909779           -0.526973           -0.646217
# std        0.286501            0.496871            0.393963
# min        0.000000           -1.000000           -1.000000
# 25%        1.000000           -0.906841           -0.965084
# 50%        1.000000           -0.663664           -0.680003
# 75%        1.000000           -0.378497           -0.559627
# max        1.000000            1.000000            1.000000
#
#        Root17DaysSeedling  Root21DaysSeedling  Root24DaysSeedling
# count        41986.000000        41986.000000        41986.000000  \
# mean            -0.700078           -0.668466           -0.668550
# std              0.379211            0.406829            0.392436
# min             -1.000000           -1.000000           -1.000000
# 25%             -0.980689           -1.000000           -0.982003
# 50%             -0.795609           -0.726665           -0.705842
# 75%             -0.601266           -0.543621           -0.485811
# max              1.000000            1.000000            1.000000
#
#        Root35DaysSeedling  Root52DaysSeedling  Shoot3DaysSeedling
# count        41986.000000        41986.000000        41986.000000  \
# mean            -0.596718           -0.669353           -0.589974
# std              0.461550            0.478191            0.445452
# min             -1.000000           -1.000000           -1.000000
# 25%             -0.937286           -1.000000           -1.000000
# 50%             -0.769184           -0.853382           -0.676286
# 75%             -0.323664           -0.537108           -0.410405
# max              1.000000            1.000000            1.000000
#
#        Shoot10DaysSeedling  Shoot14DaysSeedling  Shoot17DaysSeedling
# count         41986.000000         41986.000000         41986.000000  \
# mean             -0.545658            -0.732749            -0.680514
# std               0.476308             0.415345             0.478795
# min              -1.000000            -1.000000            -1.000000
# 25%              -0.906055            -1.000000            -1.000000
# 50%              -0.694063            -0.924976            -0.954040
# 75%              -0.262116            -0.513759            -0.420386
# max               1.000000             1.000000             1.000000
#
#        Shoot21DaysSeedling  Shoot35DaysSeedling  Leaf21DaysSeedling
# count         41986.000000         41986.000000        41986.000000  \
# mean             -0.658839            -0.559047           -0.826077
# std               0.464464             0.505545            0.331491
# min              -1.000000            -1.000000           -1.000000
# 25%              -1.000000            -0.962199           -1.000000
# 50%              -0.871560            -0.698696           -0.951894
# 75%              -0.440577            -0.352995           -0.869982
# max               1.000000             1.000000            1.000000
#
#        Leaf45DaysOldPlant
# count        41986.000000
# mean            -0.585725
# std              0.399673
# min             -1.000000
# 25%             -0.902160
# 50%             -0.643376
# 75%             -0.453136
# max              1.000000
# Summary of Y:
#  count       41986
# unique          6
# top       drought
# freq        13772
# Name: Trait, dtype: object
# Trait
# cold            5887
# drought        13772
# heat            8297
# salt            7662
# stress          6229
# submergence      139
# dtype: int64

# %%
class RBFLayer(Layer):
    def __init__(self, units, gamma, **kwargs):
        super(RBFLayer, self).__init__(**kwargs)
        self.units = units
        self.gamma = K.cast_to_floatx(gamma)

    def build(self, input_shape):
#         print(input_shape)
#         print(self.units)
        self.mu = self.add_weight(name='mu',
                                  shape=(int(input_shape[1]), self.units),
                                  initializer='uniform',
                                  trainable=True)
        super(RBFLayer, self).build(input_shape)

    def call(self, inputs):
        diff = K.expand_dims(inputs) - self.mu
        l2 = K.sum(K.pow(diff, 2), axis=1)
        res = K.exp(-1 * self.gamma * l2)
        return res

    def compute_output_shape(self, input_shape):
        return (input_shape[0], self.units)

# %%
# prepare target data
def prepare_targets(y_train, y_test):
	ohe = OneHotEncoder()
		
	y_train_enc = ohe.fit_transform(y_train)
	y_test_enc = ohe.transform(y_test)
	
	y_train_enc = y_train_enc.toarray()
	y_test_enc = y_test_enc.toarray()

	return y_train_enc, y_test_enc

# %%
# define baseline model (RBFN)
def RBFN_model():

    model = Sequential()
    model.add(Flatten(input_shape=(20,)))
    #add the RBF layer
    model.add(RBFLayer(10, 0.5))
    
    model.add(Dense(60, input_dim=20, activation='relu',bias_initializer='normal',kernel_regularizer=regularizers.l2(0.0001)))
    model.add(Dense(20,bias_initializer='normal',activation='relu',kernel_regularizer=regularizers.l2(0.0001)))
    model.add(Dense(20,bias_initializer='normal',activation='relu',kernel_regularizer=regularizers.l2(0.0001)))
    model.add(Dense(6,kernel_initializer='normal', activation='softmax')) #softmax for multi-class classification, num_classes = 6

    # Compile model
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %%
def accuracy(confusion_matrix):
   diagonal_sum = confusion_matrix.trace()
   sum_of_all_elements = confusion_matrix.sum()
   return diagonal_sum / sum_of_all_elements

# %%
def draw_confusion_matrix(cm):
    plt.figure(figsize=(12,8))
    sns.heatmap(cm,annot=True,fmt="d", center=0, cmap='autumn') 
    plt.title("Confusion Matrix")
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=1)

# prepare output data
y_train_enc, y_test_enc = prepare_targets(y_train, y_test)

# %%
# Define the number of folds for k-fold cross-validation
k = 2

# Define the cross-validation method
cv_method = StratifiedKFold(n_splits=k)

# Initialize the list to store the training, validation and test accuracy and loss of each fold
train_accuracy = []
train_loss = []
val_accuracy = []
val_loss = []
test_accuracy = []
models = []
hist = []

# Loop over the folds
for fold, (train_index, val_index) in enumerate(cv_method.split(X_train, y_train)):
    print("Fold:", fold+1)

    # Split the data into train and validation sets using the current fold index
    X_train_fold  = X_train[train_index]
    y_train_fold  = y_train[train_index]
    X_val_fold = X_train[val_index]
    y_val_fold = y_train[val_index]

    # Prepare the target data
    y_train_fold_enc, y_val_fold_enc = prepare_targets(y_train_fold, y_val_fold)

    # Build the model
    model = RBFN_model()

    # Fit the model to the training data for the current fold
    history = model.fit(X_train_fold,y_train_fold_enc, epochs=80, batch_size=5, verbose=1, validation_split = 0.33)
    
    # Evaluate the model on the validation data for the current fold
    val_scores = model.evaluate(X_val_fold, y_val_fold_enc, verbose=0)
    val_accuracy.append(val_scores[1])
    val_loss.append(val_scores[0])

    # Evaluate the model on the test data for the current fold
    test_scores = model.evaluate(X_test, y_test_enc, verbose=0)
    test_accuracy.append(test_scores[1])

    # add the model to the list of models
    models.append(model)
    hist.append(history)

    # store the training accuracy and loss for each fold
    train_accuracy.append(history.history['accuracy'])
    train_loss.append(history.history['loss'])
      
    # Print the test and validation accuracy and loss for the current fold
    print("Validation Accuracy:", val_scores[1])
    print("Validation Loss:", val_scores[0])
    print("Test Accuracy:", test_scores[1])
    print("Test Loss:", test_scores[0])

        
# Calculate the average test and validation accuracy and loss across all folds
avg_test_acc = sum(test_accuracy) / len(test_accuracy)
avg_val_acc = sum(val_accuracy) / len(val_accuracy)
avg_val_loss = sum(val_loss) / len(val_loss)

# Print the average validation and test accuracy and loss
print("Average Validation Accuracy:", avg_val_acc)
print("Average Validation Loss:",avg_val_loss)
print("Average Test Accuracy:", avg_test_acc)
# Out:
# Fold: 1
# Epoch 1/80
# 1885/1885 [==============================] - 11s 4ms/step - loss: 1.5860 - accuracy: 0.3251 - val_loss: 1.5676 - val_accuracy: 0.3283
# Epoch 2/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 1.5558 - accuracy: 0.3262 - val_loss: 1.5540 - val_accuracy: 0.3283
# Epoch 3/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.5489 - accuracy: 0.3262 - val_loss: 1.5509 - val_accuracy: 0.3283
# Epoch 4/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.5451 - accuracy: 0.3262 - val_loss: 1.5508 - val_accuracy: 0.3283
# Epoch 5/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.5427 - accuracy: 0.3262 - val_loss: 1.5466 - val_accuracy: 0.3283
# Epoch 6/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.5410 - accuracy: 0.3262 - val_loss: 1.5434 - val_accuracy: 0.3283
# Epoch 7/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.5373 - accuracy: 0.3262 - val_loss: 1.5416 - val_accuracy: 0.3283
# Epoch 8/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.5314 - accuracy: 0.3262 - val_loss: 1.5294 - val_accuracy: 0.3283
# Epoch 9/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 1.4929 - accuracy: 0.3403 - val_loss: 1.4492 - val_accuracy: 0.3789
# Epoch 10/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.4254 - accuracy: 0.3864 - val_loss: 1.4254 - val_accuracy: 0.3871
# Epoch 11/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 1.3963 - accuracy: 0.4015 - val_loss: 1.3972 - val_accuracy: 0.4082
# Epoch 12/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.3773 - accuracy: 0.4134 - val_loss: 1.3878 - val_accuracy: 0.4115
# Epoch 13/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 1.3645 - accuracy: 0.4163 - val_loss: 1.3799 - val_accuracy: 0.4134
# Epoch 14/80
# 1885/1885 [==============================] - 12s 6ms/step - loss: 1.3567 - accuracy: 0.4175 - val_loss: 1.3806 - val_accuracy: 0.4115
# Epoch 15/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.3486 - accuracy: 0.4170 - val_loss: 1.3733 - val_accuracy: 0.4149
# Epoch 16/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.3435 - accuracy: 0.4173 - val_loss: 1.3654 - val_accuracy: 0.4121
# Epoch 17/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 1.3395 - accuracy: 0.4175 - val_loss: 1.3597 - val_accuracy: 0.4171
# Epoch 18/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 1.3363 - accuracy: 0.4172 - val_loss: 1.3615 - val_accuracy: 0.4138
# Epoch 19/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.3333 - accuracy: 0.4207 - val_loss: 1.3524 - val_accuracy: 0.4270
# Epoch 20/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.3289 - accuracy: 0.4240 - val_loss: 1.3515 - val_accuracy: 0.4214
# Epoch 21/80
# 1885/1885 [==============================] - 8s 4ms/step - loss: 1.3274 - accuracy: 0.4223 - val_loss: 1.3486 - val_accuracy: 0.4153
# Epoch 22/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.3244 - accuracy: 0.4224 - val_loss: 1.3596 - val_accuracy: 0.4110
# Epoch 23/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.3206 - accuracy: 0.4225 - val_loss: 1.3481 - val_accuracy: 0.4125
# Epoch 24/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.3160 - accuracy: 0.4281 - val_loss: 1.3336 - val_accuracy: 0.4209
# Epoch 25/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.3114 - accuracy: 0.4354 - val_loss: 1.3336 - val_accuracy: 0.4315
# Epoch 26/80
# 1885/1885 [==============================] - 6s 3ms/step - loss: 1.3032 - accuracy: 0.4403 - val_loss: 1.3353 - val_accuracy: 0.4276
# Epoch 27/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 1.2972 - accuracy: 0.4410 - val_loss: 1.3143 - val_accuracy: 0.4343
# Epoch 28/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.2914 - accuracy: 0.4467 - val_loss: 1.3071 - val_accuracy: 0.4390
# Epoch 29/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 1.2822 - accuracy: 0.4542 - val_loss: 1.2906 - val_accuracy: 0.4515
# Epoch 30/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.2653 - accuracy: 0.4610 - val_loss: 1.2752 - val_accuracy: 0.4623
# Epoch 31/80
# 1885/1885 [==============================] - 10s 6ms/step - loss: 1.2486 - accuracy: 0.4693 - val_loss: 1.2763 - val_accuracy: 0.4537
# Epoch 32/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.2379 - accuracy: 0.4747 - val_loss: 1.2637 - val_accuracy: 0.4582
# Epoch 33/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 1.2277 - accuracy: 0.4781 - val_loss: 1.2500 - val_accuracy: 0.4662
# Epoch 34/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 1.2144 - accuracy: 0.4785 - val_loss: 1.2286 - val_accuracy: 0.4787
# Epoch 35/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 1.2065 - accuracy: 0.4786 - val_loss: 1.2258 - val_accuracy: 0.4810
# Epoch 36/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.1971 - accuracy: 0.4842 - val_loss: 1.2138 - val_accuracy: 0.4804
# Epoch 37/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 1.1909 - accuracy: 0.4810 - val_loss: 1.2180 - val_accuracy: 0.4759
# Epoch 38/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 1.1848 - accuracy: 0.4874 - val_loss: 1.2075 - val_accuracy: 0.4823
# Epoch 39/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 1.1777 - accuracy: 0.4893 - val_loss: 1.2050 - val_accuracy: 0.4914
# Epoch 40/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 1.1735 - accuracy: 0.4899 - val_loss: 1.2028 - val_accuracy: 0.4897
# Epoch 41/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.1665 - accuracy: 0.4956 - val_loss: 1.1977 - val_accuracy: 0.4912
# Epoch 42/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 1.1613 - accuracy: 0.4922 - val_loss: 1.2029 - val_accuracy: 0.4933
# Epoch 43/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 1.1534 - accuracy: 0.5020 - val_loss: 1.1863 - val_accuracy: 0.4996
# Epoch 44/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 1.1469 - accuracy: 0.5032 - val_loss: 1.1962 - val_accuracy: 0.4935
# Epoch 45/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 1.1424 - accuracy: 0.5064 - val_loss: 1.1840 - val_accuracy: 0.5009
# Epoch 46/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 1.1380 - accuracy: 0.5058 - val_loss: 1.1734 - val_accuracy: 0.5024
# Epoch 47/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 1.1338 - accuracy: 0.5055 - val_loss: 1.1719 - val_accuracy: 0.5073
# Epoch 48/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 1.1291 - accuracy: 0.5059 - val_loss: 1.1649 - val_accuracy: 0.5043
# Epoch 49/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 1.1267 - accuracy: 0.5061 - val_loss: 1.1714 - val_accuracy: 0.5062
# Epoch 50/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 1.1202 - accuracy: 0.5110 - val_loss: 1.1644 - val_accuracy: 0.5026
# Epoch 51/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.1164 - accuracy: 0.5108 - val_loss: 1.1563 - val_accuracy: 0.5056
# Epoch 52/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 1.1141 - accuracy: 0.5106 - val_loss: 1.1591 - val_accuracy: 0.5058
# Epoch 53/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 1.1076 - accuracy: 0.5144 - val_loss: 1.1446 - val_accuracy: 0.5082
# Epoch 54/80
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.1061 - accuracy: 0.5113 - val_loss: 1.1463 - val_accuracy: 0.5075
# Epoch 55/80
# 1885/1885 [==============================] - 8s 4ms/step - loss: 1.1033 - accuracy: 0.5119 - val_loss: 1.1663 - val_accuracy: 0.4907
# Epoch 56/80
# 1885/1885 [==============================] - 7s 4ms/step - loss: 1.1001 - accuracy: 0.5120 - val_loss: 1.1415 - val_accuracy: 0.5060
# Epoch 57/80
# 1885/1885 [==============================] - 13s 7ms/step - loss: 1.0964 - accuracy: 0.5143 - val_loss: 1.1550 - val_accuracy: 0.5043
# Epoch 58/80
# 1885/1885 [==============================] - 14s 8ms/step - loss: 1.0912 - accuracy: 0.5193 - val_loss: 1.1319 - val_accuracy: 0.5211
# Epoch 59/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.0858 - accuracy: 0.5154 - val_loss: 1.1209 - val_accuracy: 0.5181
# Epoch 60/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 1.0811 - accuracy: 0.5202 - val_loss: 1.1434 - val_accuracy: 0.5215
# Epoch 61/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.0778 - accuracy: 0.5226 - val_loss: 1.1166 - val_accuracy: 0.5080
# Epoch 62/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.0728 - accuracy: 0.5187 - val_loss: 1.1158 - val_accuracy: 0.5118
# Epoch 63/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.0701 - accuracy: 0.5203 - val_loss: 1.1029 - val_accuracy: 0.5134
# Epoch 64/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.0657 - accuracy: 0.5202 - val_loss: 1.1063 - val_accuracy: 0.5153
# Epoch 65/80
# 1885/1885 [==============================] - 8s 4ms/step - loss: 1.0601 - accuracy: 0.5222 - val_loss: 1.1078 - val_accuracy: 0.5185
# Epoch 66/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.0576 - accuracy: 0.5234 - val_loss: 1.1100 - val_accuracy: 0.5108
# Epoch 67/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.0538 - accuracy: 0.5223 - val_loss: 1.1371 - val_accuracy: 0.5116
# Epoch 68/80
# 1885/1885 [==============================] - 8s 4ms/step - loss: 1.0491 - accuracy: 0.5183 - val_loss: 1.0967 - val_accuracy: 0.5177
# Epoch 69/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.0453 - accuracy: 0.5228 - val_loss: 1.0909 - val_accuracy: 0.5140
# Epoch 70/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.0428 - accuracy: 0.5253 - val_loss: 1.0996 - val_accuracy: 0.5088
# Epoch 71/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.0369 - accuracy: 0.5216 - val_loss: 1.0784 - val_accuracy: 0.5259
# Epoch 72/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.0363 - accuracy: 0.5322 - val_loss: 1.0873 - val_accuracy: 0.5110
# Epoch 73/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.0319 - accuracy: 0.5217 - val_loss: 1.0903 - val_accuracy: 0.5166
# Epoch 74/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.0291 - accuracy: 0.5283 - val_loss: 1.0976 - val_accuracy: 0.5069
# Epoch 75/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.0255 - accuracy: 0.5314 - val_loss: 1.0684 - val_accuracy: 0.5263
# Epoch 76/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.0270 - accuracy: 0.5274 - val_loss: 1.0775 - val_accuracy: 0.5226
# Epoch 77/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.0230 - accuracy: 0.5310 - val_loss: 1.1019 - val_accuracy: 0.5093
# Epoch 78/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.0184 - accuracy: 0.5270 - val_loss: 1.0681 - val_accuracy: 0.5220
# Epoch 79/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 1.0173 - accuracy: 0.5290 - val_loss: 1.0547 - val_accuracy: 0.5276
# Epoch 80/80
# 1885/1885 [==============================] - 16s 8ms/step - loss: 1.0150 - accuracy: 0.5300 - val_loss: 1.0621 - val_accuracy: 0.5121
# Validation Accuracy: 0.5206540822982788
# Validation Loss: 1.0603837966918945
# Test Accuracy: 0.5282909870147705
# Test Loss: 1.0422230958938599
# Fold: 2
# Epoch 1/80
# 1885/1885 [==============================] - 20s 8ms/step - loss: 1.5881 - accuracy: 0.3218 - val_loss: 1.5506 - val_accuracy: 0.3376
# Epoch 2/80
# 1885/1885 [==============================] - 15s 8ms/step - loss: 1.5575 - accuracy: 0.3218 - val_loss: 1.5402 - val_accuracy: 0.3376
# Epoch 3/80
# 1885/1885 [==============================] - 16s 8ms/step - loss: 1.5494 - accuracy: 0.3218 - val_loss: 1.5340 - val_accuracy: 0.3376
# Epoch 4/80
# 1885/1885 [==============================] - 13s 7ms/step - loss: 1.5469 - accuracy: 0.3218 - val_loss: 1.5323 - val_accuracy: 0.3376
# Epoch 5/80
# 1885/1885 [==============================] - 13s 7ms/step - loss: 1.5427 - accuracy: 0.3218 - val_loss: 1.5406 - val_accuracy: 0.3376
# Epoch 6/80
# 1885/1885 [==============================] - 15s 8ms/step - loss: 1.5410 - accuracy: 0.3218 - val_loss: 1.5282 - val_accuracy: 0.3376
# Epoch 7/80
# 1885/1885 [==============================] - 14s 7ms/step - loss: 1.5375 - accuracy: 0.3218 - val_loss: 1.5244 - val_accuracy: 0.3376
# Epoch 8/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.5350 - accuracy: 0.3209 - val_loss: 1.5225 - val_accuracy: 0.3376
# Epoch 9/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.5324 - accuracy: 0.3218 - val_loss: 1.5195 - val_accuracy: 0.3376
# Epoch 10/80
# 1885/1885 [==============================] - 12s 6ms/step - loss: 1.5311 - accuracy: 0.3218 - val_loss: 1.5195 - val_accuracy: 0.3376
# Epoch 11/80
# 1885/1885 [==============================] - 14s 7ms/step - loss: 1.5252 - accuracy: 0.3218 - val_loss: 1.5101 - val_accuracy: 0.3376
# Epoch 12/80
# 1885/1885 [==============================] - 14s 7ms/step - loss: 1.4762 - accuracy: 0.3403 - val_loss: 1.4360 - val_accuracy: 0.3733
# Epoch 13/80
# 1885/1885 [==============================] - 14s 8ms/step - loss: 1.4221 - accuracy: 0.3722 - val_loss: 1.4128 - val_accuracy: 0.3817
# Epoch 14/80
# 1885/1885 [==============================] - 14s 8ms/step - loss: 1.4076 - accuracy: 0.3795 - val_loss: 1.3988 - val_accuracy: 0.3955
# Epoch 15/80
# 1885/1885 [==============================] - 14s 7ms/step - loss: 1.3921 - accuracy: 0.3884 - val_loss: 1.3845 - val_accuracy: 0.4080
# Epoch 16/80
# 1885/1885 [==============================] - 13s 7ms/step - loss: 1.3733 - accuracy: 0.4020 - val_loss: 1.3693 - val_accuracy: 0.4082
# Epoch 17/80
# 1885/1885 [==============================] - 16s 8ms/step - loss: 1.3635 - accuracy: 0.4058 - val_loss: 1.3592 - val_accuracy: 0.4149
# Epoch 18/80
# 1885/1885 [==============================] - 17s 9ms/step - loss: 1.3544 - accuracy: 0.4087 - val_loss: 1.3498 - val_accuracy: 0.4218
# Epoch 19/80
# 1885/1885 [==============================] - 17s 9ms/step - loss: 1.3499 - accuracy: 0.4123 - val_loss: 1.3528 - val_accuracy: 0.4280
# Epoch 20/80
# 1885/1885 [==============================] - 16s 8ms/step - loss: 1.3447 - accuracy: 0.4188 - val_loss: 1.3447 - val_accuracy: 0.4261
# Epoch 21/80
# 1885/1885 [==============================] - 16s 8ms/step - loss: 1.3408 - accuracy: 0.4219 - val_loss: 1.3430 - val_accuracy: 0.4240
# Epoch 22/80
# 1885/1885 [==============================] - 16s 9ms/step - loss: 1.3382 - accuracy: 0.4232 - val_loss: 1.3424 - val_accuracy: 0.4233
# Epoch 23/80
# 1885/1885 [==============================] - 15s 8ms/step - loss: 1.3341 - accuracy: 0.4247 - val_loss: 1.3357 - val_accuracy: 0.4382
# Epoch 24/80
# 1885/1885 [==============================] - 15s 8ms/step - loss: 1.3310 - accuracy: 0.4263 - val_loss: 1.3329 - val_accuracy: 0.4291
# Epoch 25/80
# 1885/1885 [==============================] - 14s 7ms/step - loss: 1.3275 - accuracy: 0.4260 - val_loss: 1.3326 - val_accuracy: 0.4362
# Epoch 26/80
# 1885/1885 [==============================] - 16s 8ms/step - loss: 1.3245 - accuracy: 0.4256 - val_loss: 1.3393 - val_accuracy: 0.4345
# Epoch 27/80
# 1885/1885 [==============================] - 15s 8ms/step - loss: 1.3225 - accuracy: 0.4293 - val_loss: 1.3186 - val_accuracy: 0.4326
# Epoch 28/80
# 1885/1885 [==============================] - 15s 8ms/step - loss: 1.3189 - accuracy: 0.4294 - val_loss: 1.3249 - val_accuracy: 0.4289
# Epoch 29/80
# 1885/1885 [==============================] - 16s 8ms/step - loss: 1.3151 - accuracy: 0.4310 - val_loss: 1.3233 - val_accuracy: 0.4403
# Epoch 30/80
# 1885/1885 [==============================] - 17s 9ms/step - loss: 1.3126 - accuracy: 0.4363 - val_loss: 1.3112 - val_accuracy: 0.4412
# Epoch 31/80
# 1885/1885 [==============================] - 18s 9ms/step - loss: 1.3089 - accuracy: 0.4418 - val_loss: 1.3083 - val_accuracy: 0.4444
# Epoch 32/80
# 1885/1885 [==============================] - 16s 9ms/step - loss: 1.3061 - accuracy: 0.4415 - val_loss: 1.3141 - val_accuracy: 0.4438
# Epoch 33/80
# 1885/1885 [==============================] - 17s 9ms/step - loss: 1.3021 - accuracy: 0.4459 - val_loss: 1.3004 - val_accuracy: 0.4556
# Epoch 34/80
# 1885/1885 [==============================] - 16s 8ms/step - loss: 1.2985 - accuracy: 0.4467 - val_loss: 1.2999 - val_accuracy: 0.4554
# Epoch 35/80
# 1885/1885 [==============================] - 14s 8ms/step - loss: 1.2950 - accuracy: 0.4521 - val_loss: 1.2968 - val_accuracy: 0.4582
# Epoch 36/80
# 1885/1885 [==============================] - 17s 9ms/step - loss: 1.2891 - accuracy: 0.4580 - val_loss: 1.3039 - val_accuracy: 0.4431
# Epoch 37/80
# 1885/1885 [==============================] - 16s 8ms/step - loss: 1.2838 - accuracy: 0.4622 - val_loss: 1.2839 - val_accuracy: 0.4692
# Epoch 38/80
# 1885/1885 [==============================] - 14s 8ms/step - loss: 1.2787 - accuracy: 0.4672 - val_loss: 1.2802 - val_accuracy: 0.4737
# Epoch 39/80
# 1885/1885 [==============================] - 13s 7ms/step - loss: 1.2712 - accuracy: 0.4724 - val_loss: 1.2793 - val_accuracy: 0.4649
# Epoch 40/80
# 1885/1885 [==============================] - 14s 7ms/step - loss: 1.2654 - accuracy: 0.4750 - val_loss: 1.3065 - val_accuracy: 0.4580
# Epoch 41/80
# 1885/1885 [==============================] - 14s 7ms/step - loss: 1.2540 - accuracy: 0.4804 - val_loss: 1.2686 - val_accuracy: 0.4713
# Epoch 42/80
# 1885/1885 [==============================] - 13s 7ms/step - loss: 1.2475 - accuracy: 0.4772 - val_loss: 1.2775 - val_accuracy: 0.4621
# Epoch 43/80
# 1885/1885 [==============================] - 13s 7ms/step - loss: 1.2439 - accuracy: 0.4802 - val_loss: 1.2523 - val_accuracy: 0.4763
# Epoch 44/80
# 1885/1885 [==============================] - 15s 8ms/step - loss: 1.2362 - accuracy: 0.4818 - val_loss: 1.2438 - val_accuracy: 0.4806
# Epoch 45/80
# 1885/1885 [==============================] - 15s 8ms/step - loss: 1.2285 - accuracy: 0.4845 - val_loss: 1.2383 - val_accuracy: 0.4821
# Epoch 46/80
# 1885/1885 [==============================] - 17s 9ms/step - loss: 1.2205 - accuracy: 0.4832 - val_loss: 1.2406 - val_accuracy: 0.4819
# Epoch 47/80
# 1885/1885 [==============================] - 17s 9ms/step - loss: 1.2144 - accuracy: 0.4842 - val_loss: 1.2263 - val_accuracy: 0.4832
# Epoch 48/80
# 1885/1885 [==============================] - 17s 9ms/step - loss: 1.2089 - accuracy: 0.4858 - val_loss: 1.2311 - val_accuracy: 0.4780
# Epoch 49/80
# 1885/1885 [==============================] - 21s 11ms/step - loss: 1.2018 - accuracy: 0.4874 - val_loss: 1.2208 - val_accuracy: 0.4873
# Epoch 50/80
# 1885/1885 [==============================] - 12s 6ms/step - loss: 1.1980 - accuracy: 0.4930 - val_loss: 1.2101 - val_accuracy: 0.4918
# Epoch 51/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 1.1937 - accuracy: 0.4922 - val_loss: 1.2179 - val_accuracy: 0.4892
# Epoch 52/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.1912 - accuracy: 0.4886 - val_loss: 1.2084 - val_accuracy: 0.4910
# Epoch 53/80
# 1885/1885 [==============================] - 8s 4ms/step - loss: 1.1875 - accuracy: 0.4934 - val_loss: 1.2153 - val_accuracy: 0.4741
# Epoch 54/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.1826 - accuracy: 0.4929 - val_loss: 1.2027 - val_accuracy: 0.4845
# Epoch 55/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.1777 - accuracy: 0.4945 - val_loss: 1.1926 - val_accuracy: 0.4886
# Epoch 56/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.1760 - accuracy: 0.4894 - val_loss: 1.1952 - val_accuracy: 0.4843
# Epoch 57/80
# 1885/1885 [==============================] - 8s 4ms/step - loss: 1.1715 - accuracy: 0.4927 - val_loss: 1.1954 - val_accuracy: 0.4860
# Epoch 58/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 1.1678 - accuracy: 0.4949 - val_loss: 1.1960 - val_accuracy: 0.4879
# Epoch 59/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 1.1621 - accuracy: 0.4938 - val_loss: 1.1931 - val_accuracy: 0.4849
# Epoch 60/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 1.1583 - accuracy: 0.4992 - val_loss: 1.1839 - val_accuracy: 0.4901
# Epoch 61/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 1.1567 - accuracy: 0.4935 - val_loss: 1.2322 - val_accuracy: 0.4718
# Epoch 62/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 1.1521 - accuracy: 0.4922 - val_loss: 1.1737 - val_accuracy: 0.4767
# Epoch 63/80
# 1885/1885 [==============================] - 21s 11ms/step - loss: 1.1487 - accuracy: 0.4972 - val_loss: 1.1973 - val_accuracy: 0.4787
# Epoch 64/80
# 1885/1885 [==============================] - 15s 8ms/step - loss: 1.1427 - accuracy: 0.4943 - val_loss: 1.1640 - val_accuracy: 0.4851
# Epoch 65/80
# 1885/1885 [==============================] - 15s 8ms/step - loss: 1.1397 - accuracy: 0.4939 - val_loss: 1.1651 - val_accuracy: 0.4705
# Epoch 66/80
# 1885/1885 [==============================] - 15s 8ms/step - loss: 1.1349 - accuracy: 0.4985 - val_loss: 1.1617 - val_accuracy: 0.4772
# Epoch 67/80
# 1885/1885 [==============================] - 16s 8ms/step - loss: 1.1302 - accuracy: 0.5024 - val_loss: 1.1652 - val_accuracy: 0.4953
# Epoch 68/80
# 1885/1885 [==============================] - 16s 9ms/step - loss: 1.1246 - accuracy: 0.5026 - val_loss: 1.1580 - val_accuracy: 0.4888
# Epoch 69/80
# 1885/1885 [==============================] - 18s 10ms/step - loss: 1.1221 - accuracy: 0.5008 - val_loss: 1.1436 - val_accuracy: 0.4920
# Epoch 70/80
# 1885/1885 [==============================] - 16s 8ms/step - loss: 1.1187 - accuracy: 0.5057 - val_loss: 1.1528 - val_accuracy: 0.4795
# Epoch 71/80
# 1885/1885 [==============================] - 15s 8ms/step - loss: 1.1139 - accuracy: 0.5067 - val_loss: 1.1384 - val_accuracy: 0.4955
# Epoch 72/80
# 1885/1885 [==============================] - 17s 9ms/step - loss: 1.1117 - accuracy: 0.5058 - val_loss: 1.1310 - val_accuracy: 0.4966
# Epoch 73/80
# 1885/1885 [==============================] - 15s 8ms/step - loss: 1.1052 - accuracy: 0.5027 - val_loss: 1.1384 - val_accuracy: 0.4897
# Epoch 74/80
# 1885/1885 [==============================] - 13s 7ms/step - loss: 1.1006 - accuracy: 0.5058 - val_loss: 1.1528 - val_accuracy: 0.4950
# Epoch 75/80
# 1885/1885 [==============================] - 14s 7ms/step - loss: 1.0966 - accuracy: 0.5032 - val_loss: 1.1270 - val_accuracy: 0.4972
# Epoch 76/80
# 1885/1885 [==============================] - 13s 7ms/step - loss: 1.0941 - accuracy: 0.5050 - val_loss: 1.1095 - val_accuracy: 0.5013
# Epoch 77/80
# 1885/1885 [==============================] - 12s 6ms/step - loss: 1.0846 - accuracy: 0.5081 - val_loss: 1.1358 - val_accuracy: 0.4959
# Epoch 78/80
# 1885/1885 [==============================] - 12s 7ms/step - loss: 1.0820 - accuracy: 0.5053 - val_loss: 1.1153 - val_accuracy: 0.5082
# Epoch 79/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 1.0767 - accuracy: 0.5123 - val_loss: 1.1402 - val_accuracy: 0.4879
# Epoch 80/80
# 1885/1885 [==============================] - 12s 6ms/step - loss: 1.0739 - accuracy: 0.5091 - val_loss: 1.1239 - val_accuracy: 0.4966
# Validation Accuracy: 0.49946674704551697
# Validation Loss: 1.1073108911514282
# Test Accuracy: 0.5020207762718201
# Test Loss: 1.1048321723937988
# Average Validation Accuracy: 0.5100604146718979
# Average Validation Loss: 1.0838473439216614
# Average Test Accuracy: 0.5151558816432953

# %%
# Select the final model based on the average test accuracy across all folds
best_model_index = test_accuracy.index(max(test_accuracy))
best_model = models[best_model_index]
best_model_history = hist[best_model_index]
best_model_train_acc = train_accuracy[best_model_index]
best_model_train_loss = train_loss[best_model_index]
best_model_val_acc = val_accuracy[best_model_index]
best_model_val_loss = val_loss[best_model_index]

# summarize history for accuracy  
plt.subplot(211)  
plt.plot(best_model_history.history['accuracy'])  
plt.plot(best_model_history.history['val_accuracy'])  
plt.title('model accuracy')  
plt.ylabel('accuracy')  
plt.xlabel('epoch')  
plt.legend(['train', 'validation'], loc='lower right')  

# summarize history for loss
plt.subplot(212)  
plt.plot(best_model_history.history['loss'])  
plt.plot(best_model_history.history['val_loss'])  
plt.title('model loss')  
plt.ylabel('loss')  
plt.xlabel('epoch')  
plt.legend(['train', 'validation'], loc='upper right')  


plt.subplots_adjust(hspace=0.7)

plt.show() 

print("Final Test Accuracy:", test_accuracy[best_model_index])
# Out:
# Final Test Accuracy: 0.5282909870147705

# %%
# Evaluate the best model on the test data
y_pred = best_model.predict(X_test)

# np.argmax() is used to convert the one-hot encoded predictions and test labels to class labels.
y_pred_label=np.argmax(y_pred, axis = 1)


rounded_ytestenc=np.argmax(y_test_enc, axis=1)

# Print the classification report
print("Classification report:\n", classification_report(rounded_ytestenc, y_pred_label))

cm = confusion_matrix(rounded_ytestenc, y_pred_label)
draw_confusion_matrix(cm)
print("Confusion matrix:\n", cm)

#Printing the accuracy
print(accuracy(cm))
# Out:
# 433/433 [==============================] - 2s 3ms/step
# c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.47      0.32      0.38      1909
#            1       0.49      0.55      0.52      4575
#            2       0.82      0.72      0.77      2787
#            3       0.34      0.22      0.27      2469
#            4       0.49      0.79      0.60      2066
#            5       0.00      0.00      0.00        50
#
#     accuracy                           0.53     13856
#    macro avg       0.44      0.43      0.42     13856
# weighted avg       0.53      0.53      0.52     13856
# Confusion matrix:
#  [[ 614  882   52   90  271    0]
#  [ 477 2527  293  621  657    0]
#  [  18  618 2010   58   83    0]
#  [ 183  991   43  542  710    0]
#  [   6  134   41  258 1627    0]
#  [   2   20    1   27    0    0]]
# 0.5282909930715936

# %%
target_names = np.array(['cold', 'drought', 'heat', 'salt', 'stress', 'submergence'])

n_classes = len(np.unique(Y)) # 6

# predict probabilities for each class
y_score = best_model.predict(X_test)


# store the fpr, tpr, and roc_auc for all averaging strategies
fpr, tpr, roc_auc = dict(), dict(), dict()

# ROC curve using micro-averaged OvR
# Compute micro-average ROC curve and ROC area
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_enc[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test_enc.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Compute macro-average ROC curve and ROC area
# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at these points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

#Plot all OvR ROC curves together
fig, ax = plt.subplots(figsize=(8, 6))

colors = cycle(["aqua", "darkorange", "cornflowerblue", "green", "purple", "red"])
for class_id, color, target_name in zip(range(n_classes), colors, target_names):
    plt.plot(
        fpr[class_id],
        tpr[class_id],
        color=color,
        lw=2,
        label=f"{target_name} (AUC = {roc_auc[class_id]:.3f})",
    )

plt.plot(
    fpr["micro"],
    tpr["micro"],
    label=f"micro-average (AUC = {roc_auc['micro']:.3f})",
    color="deeppink",
    linestyle=":",
    linewidth=4,
)

plt.plot(
    fpr["macro"],
    tpr["macro"],
    label=f"macro-average (AUC = {roc_auc['macro']:.3f})",
    color="navy",
    linestyle=":",
    linewidth=4,
)



plt.plot([0, 1], [0, 1], "k--", label="chance level (AUC = 0.5)")
plt.axis("square")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("One-vs-Rest multiclass ROC")
plt.legend(loc="lower right")
plt.show()
# Out:
# 433/433 [==============================] - 1s 3ms/step

# %%
import pickle

filepath = 'RBFN_roc.pkl'
data = {'RBFN_fpr_macro': fpr['macro'],
        'RBFN_tpr_macro': tpr['macro'],
        'RBFN_auc_macro': roc_auc['macro']}

with open(filepath,'wb') as f:
    pickle.dump(data,f)

# %%
#created for the result.csv
dataTrait1 = df.drop(columns=["Class"]) #create for csv output
X1 = dataTrait1.drop(["Trait"], axis=1) #create for csv output

# split into train and test sets
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, Y, test_size=0.33, random_state=1)

# extract OsID from test data 
OsID_test = X_test1['OsID'].values

trait_names = (['cold', 'drought', 'heat', 'salt', 'stress', 'submergence'])

# map class labels to target names
true_class = [trait_names[i] for i in rounded_ytestenc]
predicted_class = [trait_names[i] for i in y_pred_label]

# create dataframe with OsID, true class, predicted class, and true/false columns
results = pd.DataFrame({
    'OsID': OsID_test,
    'True Class': true_class,
    'Predicted Class': predicted_class,
    'True/False': [x == y for x, y in zip(true_class, predicted_class)]})


# display dataframe
print(results.head())

# save results_df to a CSV file
results.to_csv('RBFN_trait classification.csv', index=False)
# Out:
#            OsID True Class Predicted Class  True/False
# 0  Os09g0522200       cold         drought       False
# 1  Os11g0592200    drought         drought        True
# 2  Os01g0699100     stress          stress        True
# 3  Os02g0126400    drought            salt       False
# 4  Os03g0669100    drought          stress       False
