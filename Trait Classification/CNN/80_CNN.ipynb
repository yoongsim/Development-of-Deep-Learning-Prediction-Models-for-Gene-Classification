# %%
from itertools import cycle

import numpy as np
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import MinMaxScaler
from keras.models import Model ,Sequential #for CNN
from keras.layers import Dense 
from sklearn.model_selection import KFold
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from keras.layers import Conv2D, Input, MaxPooling2D, Dropout, Flatten, Dense, Activation
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.model_selection import StratifiedKFold
from keras import regularizers

# %%
#fixed random seed for reproducibility 
np.random.seed(0)

# %%
# load dataset (input variables = X, output variables = Y)
df = pd.read_csv("TrainingData.csv")

dataTrait = df.drop(columns=["OsID", "Class"])# exclude OSID and Class Column
print("Summary of dataTrait:\n",dataTrait.describe())


X = dataTrait.drop(['Trait'], axis=1) # exclude log_2FoldChange and trait columns
Y = dataTrait['Trait']


print("Shape of X:\n",X.shape)
print("Shape of Y:\n",Y.shape)

# Statistical summary of the variables
print("Summary of X:\n",X.describe())
print("Summary of Y:\n",Y.describe())

# Check for class imbalance
print(df.groupby(Y).size())

# change both input and target variables datatype to ndarray
X = X.values # 2-D array

# select target variable 

Y = Y.values #1-D array
Y = Y.reshape(-1, 1)
# Out:
# Summary of dataTrait:
#         log_2FoldChange            ET  CoExpression           PCC
# count     41986.000000  41986.000000  41986.000000  41986.000000  \
# mean         -0.040210      1.386724      0.988687     -0.365709
# std           0.389447      0.796948      0.105762      0.462418
# min          -1.000000      0.000000      0.000000     -1.000000
# 25%          -0.251534      1.000000      1.000000     -0.750074
# 50%           0.030675      2.000000      1.000000     -0.449089
# 75%           0.251534      2.000000      1.000000     -0.055126
# max           1.000000      2.000000      1.000000      1.000000
#
#                 PPI  Root10DaysSeedling  Root14DaysSeedling
# count  41986.000000        41986.000000        41986.000000  \
# mean       0.909779           -0.526973           -0.646217
# std        0.286501            0.496871            0.393963
# min        0.000000           -1.000000           -1.000000
# 25%        1.000000           -0.906841           -0.965084
# 50%        1.000000           -0.663664           -0.680003
# 75%        1.000000           -0.378497           -0.559627
# max        1.000000            1.000000            1.000000
#
#        Root17DaysSeedling  Root21DaysSeedling  Root24DaysSeedling
# count        41986.000000        41986.000000        41986.000000  \
# mean            -0.700078           -0.668466           -0.668550
# std              0.379211            0.406829            0.392436
# min             -1.000000           -1.000000           -1.000000
# 25%             -0.980689           -1.000000           -0.982003
# 50%             -0.795609           -0.726665           -0.705842
# 75%             -0.601266           -0.543621           -0.485811
# max              1.000000            1.000000            1.000000
#
#        Root35DaysSeedling  Root52DaysSeedling  Shoot3DaysSeedling
# count        41986.000000        41986.000000        41986.000000  \
# mean            -0.596718           -0.669353           -0.589974
# std              0.461550            0.478191            0.445452
# min             -1.000000           -1.000000           -1.000000
# 25%             -0.937286           -1.000000           -1.000000
# 50%             -0.769184           -0.853382           -0.676286
# 75%             -0.323664           -0.537108           -0.410405
# max              1.000000            1.000000            1.000000
#
#        Shoot10DaysSeedling  Shoot14DaysSeedling  Shoot17DaysSeedling
# count         41986.000000         41986.000000         41986.000000  \
# mean             -0.545658            -0.732749            -0.680514
# std               0.476308             0.415345             0.478795
# min              -1.000000            -1.000000            -1.000000
# 25%              -0.906055            -1.000000            -1.000000
# 50%              -0.694063            -0.924976            -0.954040
# 75%              -0.262116            -0.513759            -0.420386
# max               1.000000             1.000000             1.000000
#
#        Shoot21DaysSeedling  Shoot35DaysSeedling  Leaf21DaysSeedling
# count         41986.000000         41986.000000        41986.000000  \
# mean             -0.658839            -0.559047           -0.826077
# std               0.464464             0.505545            0.331491
# min              -1.000000            -1.000000           -1.000000
# 25%              -1.000000            -0.962199           -1.000000
# 50%              -0.871560            -0.698696           -0.951894
# 75%              -0.440577            -0.352995           -0.869982
# max               1.000000             1.000000            1.000000
#
#        Leaf45DaysOldPlant
# count        41986.000000
# mean            -0.585725
# std              0.399673
# min             -1.000000
# 25%             -0.902160
# 50%             -0.643376
# 75%             -0.453136
# max              1.000000
# Shape of X:
#  (41986, 20)
# Shape of Y:
#  (41986,)
# Summary of X:
#         log_2FoldChange            ET  CoExpression           PCC
# count     41986.000000  41986.000000  41986.000000  41986.000000  \
# mean         -0.040210      1.386724      0.988687     -0.365709
# std           0.389447      0.796948      0.105762      0.462418
# min          -1.000000      0.000000      0.000000     -1.000000
# 25%          -0.251534      1.000000      1.000000     -0.750074
# 50%           0.030675      2.000000      1.000000     -0.449089
# 75%           0.251534      2.000000      1.000000     -0.055126
# max           1.000000      2.000000      1.000000      1.000000
#
#                 PPI  Root10DaysSeedling  Root14DaysSeedling
# count  41986.000000        41986.000000        41986.000000  \
# mean       0.909779           -0.526973           -0.646217
# std        0.286501            0.496871            0.393963
# min        0.000000           -1.000000           -1.000000
# 25%        1.000000           -0.906841           -0.965084
# 50%        1.000000           -0.663664           -0.680003
# 75%        1.000000           -0.378497           -0.559627
# max        1.000000            1.000000            1.000000
#
#        Root17DaysSeedling  Root21DaysSeedling  Root24DaysSeedling
# count        41986.000000        41986.000000        41986.000000  \
# mean            -0.700078           -0.668466           -0.668550
# std              0.379211            0.406829            0.392436
# min             -1.000000           -1.000000           -1.000000
# 25%             -0.980689           -1.000000           -0.982003
# 50%             -0.795609           -0.726665           -0.705842
# 75%             -0.601266           -0.543621           -0.485811
# max              1.000000            1.000000            1.000000
#
#        Root35DaysSeedling  Root52DaysSeedling  Shoot3DaysSeedling
# count        41986.000000        41986.000000        41986.000000  \
# mean            -0.596718           -0.669353           -0.589974
# std              0.461550            0.478191            0.445452
# min             -1.000000           -1.000000           -1.000000
# 25%             -0.937286           -1.000000           -1.000000
# 50%             -0.769184           -0.853382           -0.676286
# 75%             -0.323664           -0.537108           -0.410405
# max              1.000000            1.000000            1.000000
#
#        Shoot10DaysSeedling  Shoot14DaysSeedling  Shoot17DaysSeedling
# count         41986.000000         41986.000000         41986.000000  \
# mean             -0.545658            -0.732749            -0.680514
# std               0.476308             0.415345             0.478795
# min              -1.000000            -1.000000            -1.000000
# 25%              -0.906055            -1.000000            -1.000000
# 50%              -0.694063            -0.924976            -0.954040
# 75%              -0.262116            -0.513759            -0.420386
# max               1.000000             1.000000             1.000000
#
#        Shoot21DaysSeedling  Shoot35DaysSeedling  Leaf21DaysSeedling
# count         41986.000000         41986.000000        41986.000000  \
# mean             -0.658839            -0.559047           -0.826077
# std               0.464464             0.505545            0.331491
# min              -1.000000            -1.000000           -1.000000
# 25%              -1.000000            -0.962199           -1.000000
# 50%              -0.871560            -0.698696           -0.951894
# 75%              -0.440577            -0.352995           -0.869982
# max               1.000000             1.000000            1.000000
#
#        Leaf45DaysOldPlant
# count        41986.000000
# mean            -0.585725
# std              0.399673
# min             -1.000000
# 25%             -0.902160
# 50%             -0.643376
# 75%             -0.453136
# max              1.000000
# Summary of Y:
#  count       41986
# unique          6
# top       drought
# freq        13772
# Name: Trait, dtype: object
# Trait
# cold            5887
# drought        13772
# heat            8297
# salt            7662
# stress          6229
# submergence      139
# dtype: int64

# %%
# prepare target data
def prepare_targets(y_train, y_test):
	ohe = OneHotEncoder()
		
	y_train_enc = ohe.fit_transform(y_train)
	y_test_enc = ohe.transform(y_test)
	
	y_train_enc = y_train_enc.toarray()
	y_test_enc = y_test_enc.toarray()

	return y_train_enc, y_test_enc

# %%
def draw_confusion_matrix(cm):
    plt.figure(figsize=(12,8))
    sns.heatmap(cm,annot=True,fmt="d", center=0, cmap='autumn') 
    plt.title("Confusion Matrix")
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
data_shape = [10,2]
X = X.reshape(41986, data_shape[0], data_shape[1])

# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=1)

X_train = X_train.astype('float32') 
X_test = X_test.astype('float32') 

X_train = X_train.reshape(X_train.shape[0], data_shape[0],data_shape[1], 1) 
X_test = X_test.reshape(X_test.shape[0], data_shape[0],data_shape[1], 1) 


X_train_size = X_train.size
X_test_size = X_test.size

print(X_train.shape)
print(X_test.shape)

# prepare output data
y_train_enc, y_test_enc = prepare_targets(y_train, y_test)
# Out:
# (28130, 10, 2, 1)
# (13856, 10, 2, 1)

# %%
#define model CNN

def CNN_model():
    model = Sequential()
    model.add(Conv2D(60, kernel_size=(5,5), activation='relu',bias_initializer='normal', input_shape=(data_shape[0],data_shape[1],1), padding= "same")) #keeps the output size same as input size (prevent down or upsampling)
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Flatten())
    model.add(Dense(20, bias_initializer='normal', activation='relu',kernel_regularizer=regularizers.l2(0.0001)))
    model.add(Dense(20, bias_initializer='normal', activation='relu',kernel_regularizer=regularizers.l2(0.0001)))
    model.add(Dense(6, kernel_initializer='normal', activation='softmax'))

    #compile model
    model.compile(loss = "categorical_crossentropy", optimizer='adam', metrics = ['accuracy']) 

    return model

model = CNN_model()

#print model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 10, 2, 60)         1560
#
#  max_pooling2d (MaxPooling2D  (None, 5, 1, 60)         0
#  )
#
#  flatten (Flatten)           (None, 300)               0
#
#  dense (Dense)               (None, 20)                6020
#
#  dense_1 (Dense)             (None, 20)                420
#
#  dense_2 (Dense)             (None, 6)                 126
#
# =================================================================
# Total params: 8,126
# Trainable params: 8,126
# Non-trainable params: 0
# _________________________________________________________________

# %%
def accuracy(confusion_matrix):
   diagonal_sum = confusion_matrix.trace()
   sum_of_all_elements = confusion_matrix.sum()
   return diagonal_sum / sum_of_all_elements

# %%
# Define the number of folds for k-fold cross-validation
k = 2

# Define the cross-validation method
cv_method = StratifiedKFold(n_splits=k)

# Initialize the list to store the training, validation and test accuracy and loss of each fold
train_accuracy = []
train_loss = []
val_accuracy = []
val_loss = []
test_accuracy = []
models = []
hist = []

# Loop over the folds
for fold, (train_index, val_index) in enumerate(cv_method.split(X_train, y_train)):
    print("Fold:", fold+1)

    # Split the data into train and validation sets using the current fold index
    X_train_fold  = X_train[train_index]
    y_train_fold  = y_train[train_index]
    X_val_fold = X_train[val_index]
    y_val_fold = y_train[val_index]

    # Prepare the target data
    y_train_fold_enc, y_val_fold_enc = prepare_targets(y_train_fold, y_val_fold)

    # Build the model
    model = CNN_model()

    # Fit the model to the training data for the current fold
    history = model.fit(X_train_fold,y_train_fold_enc, epochs=80, batch_size=5, verbose=1, validation_split = 0.33)
    
    # Evaluate the model on the validation data for the current fold
    val_scores = model.evaluate(X_val_fold, y_val_fold_enc, verbose=0)
    val_accuracy.append(val_scores[1])
    val_loss.append(val_scores[0])

    # Evaluate the model on the test data for the current fold
    test_scores = model.evaluate(X_test, y_test_enc, verbose=0)
    test_accuracy.append(test_scores[1])

    # add the model to the list of models
    models.append(model)
    hist.append(history)

    # store the training accuracy and loss for each fold
    train_accuracy.append(history.history['accuracy'])
    train_loss.append(history.history['loss'])
      
    # Print the test and validation accuracy and loss for the current fold
    print("Validation Accuracy:", val_scores[1])
    print("Validation Loss:", val_scores[0])
    print("Test Accuracy:", test_scores[1])
    print("Test Loss:", test_scores[0])

        
# Calculate the average test and validation accuracy and loss across all folds
avg_test_acc = sum(test_accuracy) / len(test_accuracy)
avg_val_acc = sum(val_accuracy) / len(val_accuracy)
avg_val_loss = sum(val_loss) / len(val_loss)

# Print the average validation and test accuracy and loss
print("Average Validation Accuracy:", avg_val_acc)
print("Average Validation Loss:",avg_val_loss)
print("Average Test Accuracy:", avg_test_acc)
# Out:
# Fold: 1
# Epoch 1/80
# 1885/1885 [==============================] - 11s 5ms/step - loss: 1.4228 - accuracy: 0.3974 - val_loss: 1.2659 - val_accuracy: 0.4655
# Epoch 2/80
# 1885/1885 [==============================] - 8s 4ms/step - loss: 1.1941 - accuracy: 0.4824 - val_loss: 1.1308 - val_accuracy: 0.5088
# Epoch 3/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 1.0964 - accuracy: 0.5002 - val_loss: 1.1674 - val_accuracy: 0.4724
# Epoch 4/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 1.0394 - accuracy: 0.5144 - val_loss: 1.0961 - val_accuracy: 0.4931
# Epoch 5/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 1.0068 - accuracy: 0.5178 - val_loss: 1.0277 - val_accuracy: 0.5198
# Epoch 6/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.9790 - accuracy: 0.5287 - val_loss: 1.0141 - val_accuracy: 0.5259
# Epoch 7/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.9588 - accuracy: 0.5346 - val_loss: 0.9742 - val_accuracy: 0.5218
# Epoch 8/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.9458 - accuracy: 0.5302 - val_loss: 0.9540 - val_accuracy: 0.5293
# Epoch 9/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 0.9307 - accuracy: 0.5411 - val_loss: 0.9548 - val_accuracy: 0.5403
# Epoch 10/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.9160 - accuracy: 0.5478 - val_loss: 0.9796 - val_accuracy: 0.5183
# Epoch 11/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.9011 - accuracy: 0.5461 - val_loss: 0.9243 - val_accuracy: 0.5424
# Epoch 12/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 0.8920 - accuracy: 0.5509 - val_loss: 0.9202 - val_accuracy: 0.5455
# Epoch 13/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 0.8854 - accuracy: 0.5552 - val_loss: 0.9213 - val_accuracy: 0.5388
# Epoch 14/80
# 1885/1885 [==============================] - 12s 7ms/step - loss: 0.8792 - accuracy: 0.5528 - val_loss: 0.9082 - val_accuracy: 0.5435
# Epoch 15/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 0.8694 - accuracy: 0.5553 - val_loss: 0.9751 - val_accuracy: 0.5330
# Epoch 16/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.8564 - accuracy: 0.5636 - val_loss: 0.8967 - val_accuracy: 0.5446
# Epoch 17/80
# 1885/1885 [==============================] - 12s 6ms/step - loss: 0.8517 - accuracy: 0.5631 - val_loss: 0.9196 - val_accuracy: 0.5379
# Epoch 18/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 0.8434 - accuracy: 0.5700 - val_loss: 0.8810 - val_accuracy: 0.5470
# Epoch 19/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 0.8415 - accuracy: 0.5638 - val_loss: 0.9309 - val_accuracy: 0.5403
# Epoch 20/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.8357 - accuracy: 0.5702 - val_loss: 0.9295 - val_accuracy: 0.5379
# Epoch 21/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.8355 - accuracy: 0.5686 - val_loss: 0.8852 - val_accuracy: 0.5530
# Epoch 22/80
# 1885/1885 [==============================] - 10s 6ms/step - loss: 0.8258 - accuracy: 0.5689 - val_loss: 0.8572 - val_accuracy: 0.5560
# Epoch 23/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.8234 - accuracy: 0.5737 - val_loss: 0.8898 - val_accuracy: 0.5595
# Epoch 24/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.8200 - accuracy: 0.5749 - val_loss: 0.8963 - val_accuracy: 0.5474
# Epoch 25/80
# 1885/1885 [==============================] - 7s 4ms/step - loss: 0.8130 - accuracy: 0.5776 - val_loss: 0.8666 - val_accuracy: 0.5478
# Epoch 26/80
# 1885/1885 [==============================] - 13s 7ms/step - loss: 0.8119 - accuracy: 0.5747 - val_loss: 0.8968 - val_accuracy: 0.5610
# Epoch 27/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 0.8060 - accuracy: 0.5739 - val_loss: 0.8616 - val_accuracy: 0.5597
# Epoch 28/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.8046 - accuracy: 0.5754 - val_loss: 0.8394 - val_accuracy: 0.5707
# Epoch 29/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 0.8007 - accuracy: 0.5751 - val_loss: 0.8518 - val_accuracy: 0.5698
# Epoch 30/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 0.7968 - accuracy: 0.5762 - val_loss: 0.8905 - val_accuracy: 0.5661
# Epoch 31/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 0.7918 - accuracy: 0.5818 - val_loss: 0.8643 - val_accuracy: 0.5562
# Epoch 32/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 0.7969 - accuracy: 0.5827 - val_loss: 0.8709 - val_accuracy: 0.5554
# Epoch 33/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 0.7877 - accuracy: 0.5850 - val_loss: 0.8237 - val_accuracy: 0.5683
# Epoch 34/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 0.7876 - accuracy: 0.5772 - val_loss: 0.8630 - val_accuracy: 0.5579
# Epoch 35/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 0.7838 - accuracy: 0.5808 - val_loss: 0.8386 - val_accuracy: 0.5584
# Epoch 36/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 0.7805 - accuracy: 0.5838 - val_loss: 0.8395 - val_accuracy: 0.5595
# Epoch 37/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 0.7809 - accuracy: 0.5896 - val_loss: 0.8359 - val_accuracy: 0.5638
# Epoch 38/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 0.7819 - accuracy: 0.5775 - val_loss: 0.8402 - val_accuracy: 0.5584
# Epoch 39/80
# 1885/1885 [==============================] - 10s 6ms/step - loss: 0.7738 - accuracy: 0.5896 - val_loss: 0.8495 - val_accuracy: 0.5692
# Epoch 40/80
# 1885/1885 [==============================] - 12s 7ms/step - loss: 0.7732 - accuracy: 0.5833 - val_loss: 0.8274 - val_accuracy: 0.5614
# Epoch 41/80
# 1885/1885 [==============================] - 13s 7ms/step - loss: 0.7707 - accuracy: 0.5870 - val_loss: 0.8426 - val_accuracy: 0.5640
# Epoch 42/80
# 1885/1885 [==============================] - 12s 7ms/step - loss: 0.7727 - accuracy: 0.5916 - val_loss: 0.8343 - val_accuracy: 0.5638
# Epoch 43/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 0.7664 - accuracy: 0.5900 - val_loss: 0.8594 - val_accuracy: 0.5631
# Epoch 44/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 0.7664 - accuracy: 0.5835 - val_loss: 0.8359 - val_accuracy: 0.5584
# Epoch 45/80
# 1885/1885 [==============================] - 12s 6ms/step - loss: 0.7657 - accuracy: 0.5961 - val_loss: 0.8225 - val_accuracy: 0.5629
# Epoch 46/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 0.7650 - accuracy: 0.5864 - val_loss: 0.8244 - val_accuracy: 0.5694
# Epoch 47/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 0.7650 - accuracy: 0.5923 - val_loss: 0.8264 - val_accuracy: 0.5627
# Epoch 48/80
# 1885/1885 [==============================] - 12s 6ms/step - loss: 0.7635 - accuracy: 0.5811 - val_loss: 0.8234 - val_accuracy: 0.5607
# Epoch 49/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 0.7583 - accuracy: 0.5863 - val_loss: 0.8372 - val_accuracy: 0.5685
# Epoch 50/80
# 1885/1885 [==============================] - 8s 4ms/step - loss: 0.7590 - accuracy: 0.5856 - val_loss: 0.8196 - val_accuracy: 0.5717
# Epoch 51/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 0.7627 - accuracy: 0.5794 - val_loss: 0.8315 - val_accuracy: 0.5668
# Epoch 52/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 0.7566 - accuracy: 0.5930 - val_loss: 0.8480 - val_accuracy: 0.5601
# Epoch 53/80
# 1885/1885 [==============================] - 17s 9ms/step - loss: 0.7537 - accuracy: 0.5894 - val_loss: 0.8390 - val_accuracy: 0.5627
# Epoch 54/80
# 1885/1885 [==============================] - 14s 7ms/step - loss: 0.7533 - accuracy: 0.5957 - val_loss: 0.8329 - val_accuracy: 0.5728
# Epoch 55/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.7541 - accuracy: 0.5935 - val_loss: 0.8485 - val_accuracy: 0.5599
# Epoch 56/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.7486 - accuracy: 0.5907 - val_loss: 0.8196 - val_accuracy: 0.5597
# Epoch 57/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.7505 - accuracy: 0.5973 - val_loss: 0.8218 - val_accuracy: 0.5657
# Epoch 58/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.7517 - accuracy: 0.5931 - val_loss: 0.9583 - val_accuracy: 0.5623
# Epoch 59/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.7505 - accuracy: 0.5938 - val_loss: 0.8364 - val_accuracy: 0.5612
# Epoch 60/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.7448 - accuracy: 0.5928 - val_loss: 0.8586 - val_accuracy: 0.5579
# Epoch 61/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.7440 - accuracy: 0.5984 - val_loss: 0.8137 - val_accuracy: 0.5700
# Epoch 62/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.7480 - accuracy: 0.5904 - val_loss: 0.8584 - val_accuracy: 0.5571
# Epoch 63/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.7449 - accuracy: 0.5938 - val_loss: 0.8406 - val_accuracy: 0.5711
# Epoch 64/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.7416 - accuracy: 0.5955 - val_loss: 0.8370 - val_accuracy: 0.5679
# Epoch 65/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.7392 - accuracy: 0.5996 - val_loss: 0.8261 - val_accuracy: 0.5702
# Epoch 66/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.7429 - accuracy: 0.5878 - val_loss: 0.8372 - val_accuracy: 0.5560
# Epoch 67/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.7403 - accuracy: 0.5993 - val_loss: 0.8059 - val_accuracy: 0.5670
# Epoch 68/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.7433 - accuracy: 0.6006 - val_loss: 0.8290 - val_accuracy: 0.5618
# Epoch 69/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.7371 - accuracy: 0.5965 - val_loss: 0.8027 - val_accuracy: 0.5741
# Epoch 70/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.7375 - accuracy: 0.5957 - val_loss: 0.8100 - val_accuracy: 0.5760
# Epoch 71/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.7386 - accuracy: 0.5956 - val_loss: 0.8263 - val_accuracy: 0.5627
# Epoch 72/80
# 1885/1885 [==============================] - 12s 6ms/step - loss: 0.7387 - accuracy: 0.6007 - val_loss: 0.8254 - val_accuracy: 0.5704
# Epoch 73/80
# 1885/1885 [==============================] - 19s 10ms/step - loss: 0.7349 - accuracy: 0.6019 - val_loss: 0.8338 - val_accuracy: 0.5773
# Epoch 74/80
# 1885/1885 [==============================] - 15s 8ms/step - loss: 0.7404 - accuracy: 0.5946 - val_loss: 0.8086 - val_accuracy: 0.5685
# Epoch 75/80
# 1885/1885 [==============================] - 17s 9ms/step - loss: 0.7332 - accuracy: 0.6037 - val_loss: 0.8100 - val_accuracy: 0.5773
# Epoch 76/80
# 1885/1885 [==============================] - 16s 9ms/step - loss: 0.7352 - accuracy: 0.6009 - val_loss: 0.8105 - val_accuracy: 0.5588
# Epoch 77/80
# 1885/1885 [==============================] - 15s 8ms/step - loss: 0.7337 - accuracy: 0.5957 - val_loss: 0.8457 - val_accuracy: 0.5573
# Epoch 78/80
# 1885/1885 [==============================] - 15s 8ms/step - loss: 0.7336 - accuracy: 0.5955 - val_loss: 0.8161 - val_accuracy: 0.5758
# Epoch 79/80
# 1885/1885 [==============================] - 16s 8ms/step - loss: 0.7319 - accuracy: 0.5996 - val_loss: 0.8003 - val_accuracy: 0.5735
# Epoch 80/80
# 1885/1885 [==============================] - 15s 8ms/step - loss: 0.7284 - accuracy: 0.5992 - val_loss: 0.8004 - val_accuracy: 0.5687
# Validation Accuracy: 0.5702097415924072
# Validation Loss: 0.790301501750946
# Test Accuracy: 0.5687066912651062
# Test Loss: 0.7923045754432678
# Fold: 2
# Epoch 1/80
# 1885/1885 [==============================] - 13s 5ms/step - loss: 1.4784 - accuracy: 0.3674 - val_loss: 1.3021 - val_accuracy: 0.4621
# Epoch 2/80
# 1885/1885 [==============================] - 13s 7ms/step - loss: 1.2326 - accuracy: 0.4721 - val_loss: 1.1552 - val_accuracy: 0.5002
# Epoch 3/80
# 1885/1885 [==============================] - 15s 8ms/step - loss: 1.1286 - accuracy: 0.5044 - val_loss: 1.0815 - val_accuracy: 0.5187
# Epoch 4/80
# 1885/1885 [==============================] - 15s 8ms/step - loss: 1.0703 - accuracy: 0.5189 - val_loss: 1.0418 - val_accuracy: 0.5194
# Epoch 5/80
# 1885/1885 [==============================] - 16s 9ms/step - loss: 1.0338 - accuracy: 0.5256 - val_loss: 1.0806 - val_accuracy: 0.4970
# Epoch 6/80
# 1885/1885 [==============================] - 16s 8ms/step - loss: 1.0008 - accuracy: 0.5363 - val_loss: 1.0712 - val_accuracy: 0.5164
# Epoch 7/80
# 1885/1885 [==============================] - 15s 8ms/step - loss: 0.9839 - accuracy: 0.5388 - val_loss: 0.9866 - val_accuracy: 0.5293
# Epoch 8/80
# 1885/1885 [==============================] - 16s 8ms/step - loss: 0.9661 - accuracy: 0.5450 - val_loss: 0.9816 - val_accuracy: 0.5308
# Epoch 9/80
# 1885/1885 [==============================] - 19s 10ms/step - loss: 0.9479 - accuracy: 0.5523 - val_loss: 0.9582 - val_accuracy: 0.5284
# Epoch 10/80
# 1885/1885 [==============================] - 18s 10ms/step - loss: 0.9365 - accuracy: 0.5531 - val_loss: 0.9717 - val_accuracy: 0.5325
# Epoch 11/80
# 1885/1885 [==============================] - 17s 9ms/step - loss: 0.9245 - accuracy: 0.5496 - val_loss: 0.9434 - val_accuracy: 0.5351
# Epoch 12/80
# 1885/1885 [==============================] - 17s 9ms/step - loss: 0.9090 - accuracy: 0.5603 - val_loss: 0.9265 - val_accuracy: 0.5483
# Epoch 13/80
# 1885/1885 [==============================] - 17s 9ms/step - loss: 0.9003 - accuracy: 0.5596 - val_loss: 0.9225 - val_accuracy: 0.5371
# Epoch 14/80
# 1885/1885 [==============================] - 17s 9ms/step - loss: 0.8897 - accuracy: 0.5617 - val_loss: 0.9460 - val_accuracy: 0.5349
# Epoch 15/80
# 1885/1885 [==============================] - 16s 8ms/step - loss: 0.8904 - accuracy: 0.5569 - val_loss: 0.9118 - val_accuracy: 0.5355
# Epoch 16/80
# 1885/1885 [==============================] - 16s 8ms/step - loss: 0.8750 - accuracy: 0.5665 - val_loss: 0.9025 - val_accuracy: 0.5317
# Epoch 17/80
# 1885/1885 [==============================] - 17s 9ms/step - loss: 0.8681 - accuracy: 0.5654 - val_loss: 0.8798 - val_accuracy: 0.5399
# Epoch 18/80
# 1885/1885 [==============================] - 17s 9ms/step - loss: 0.8666 - accuracy: 0.5636 - val_loss: 0.8882 - val_accuracy: 0.5409
# Epoch 19/80
# 1885/1885 [==============================] - 17s 9ms/step - loss: 0.8565 - accuracy: 0.5673 - val_loss: 0.8956 - val_accuracy: 0.5498
# Epoch 20/80
# 1885/1885 [==============================] - 18s 9ms/step - loss: 0.8462 - accuracy: 0.5714 - val_loss: 0.9112 - val_accuracy: 0.5409
# Epoch 21/80
# 1885/1885 [==============================] - 19s 10ms/step - loss: 0.8452 - accuracy: 0.5707 - val_loss: 0.8669 - val_accuracy: 0.5465
# Epoch 22/80
# 1885/1885 [==============================] - 17s 9ms/step - loss: 0.8379 - accuracy: 0.5695 - val_loss: 0.9156 - val_accuracy: 0.5442
# Epoch 23/80
# 1885/1885 [==============================] - 18s 9ms/step - loss: 0.8378 - accuracy: 0.5699 - val_loss: 0.8561 - val_accuracy: 0.5528
# Epoch 24/80
# 1885/1885 [==============================] - 17s 9ms/step - loss: 0.8284 - accuracy: 0.5726 - val_loss: 0.8496 - val_accuracy: 0.5502
# Epoch 25/80
# 1885/1885 [==============================] - 16s 9ms/step - loss: 0.8261 - accuracy: 0.5742 - val_loss: 0.9250 - val_accuracy: 0.5271
# Epoch 26/80
# 1885/1885 [==============================] - 19s 10ms/step - loss: 0.8178 - accuracy: 0.5732 - val_loss: 0.8477 - val_accuracy: 0.5519
# Epoch 27/80
# 1885/1885 [==============================] - 17s 9ms/step - loss: 0.8135 - accuracy: 0.5779 - val_loss: 0.8604 - val_accuracy: 0.5487
# Epoch 28/80
# 1885/1885 [==============================] - 15s 8ms/step - loss: 0.8119 - accuracy: 0.5805 - val_loss: 0.8528 - val_accuracy: 0.5571
# Epoch 29/80
# 1885/1885 [==============================] - 15s 8ms/step - loss: 0.8054 - accuracy: 0.5833 - val_loss: 0.8435 - val_accuracy: 0.5530
# Epoch 30/80
# 1885/1885 [==============================] - 15s 8ms/step - loss: 0.8082 - accuracy: 0.5769 - val_loss: 0.8632 - val_accuracy: 0.5532
# Epoch 31/80
# 1885/1885 [==============================] - 15s 8ms/step - loss: 0.8014 - accuracy: 0.5869 - val_loss: 0.9414 - val_accuracy: 0.5448
# Epoch 32/80
# 1885/1885 [==============================] - 14s 8ms/step - loss: 0.7970 - accuracy: 0.5823 - val_loss: 0.8652 - val_accuracy: 0.5543
# Epoch 33/80
# 1885/1885 [==============================] - 16s 8ms/step - loss: 0.7904 - accuracy: 0.5825 - val_loss: 0.8635 - val_accuracy: 0.5528
# Epoch 34/80
# 1885/1885 [==============================] - 18s 10ms/step - loss: 0.7950 - accuracy: 0.5804 - val_loss: 0.8167 - val_accuracy: 0.5567
# Epoch 35/80
# 1885/1885 [==============================] - 18s 10ms/step - loss: 0.7872 - accuracy: 0.5822 - val_loss: 0.8750 - val_accuracy: 0.5543
# Epoch 36/80
# 1885/1885 [==============================] - 18s 10ms/step - loss: 0.7912 - accuracy: 0.5769 - val_loss: 0.8145 - val_accuracy: 0.5584
# Epoch 37/80
# 1885/1885 [==============================] - 20s 11ms/step - loss: 0.7839 - accuracy: 0.5814 - val_loss: 0.8352 - val_accuracy: 0.5659
# Epoch 38/80
# 1885/1885 [==============================] - 19s 10ms/step - loss: 0.7814 - accuracy: 0.5865 - val_loss: 0.8209 - val_accuracy: 0.5603
# Epoch 39/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 0.7833 - accuracy: 0.5838 - val_loss: 0.8250 - val_accuracy: 0.5539
# Epoch 40/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 0.7803 - accuracy: 0.5843 - val_loss: 0.8320 - val_accuracy: 0.5567
# Epoch 41/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 0.7836 - accuracy: 0.5864 - val_loss: 0.8230 - val_accuracy: 0.5590
# Epoch 42/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.7783 - accuracy: 0.5866 - val_loss: 0.8103 - val_accuracy: 0.5648
# Epoch 43/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.7747 - accuracy: 0.5800 - val_loss: 0.8185 - val_accuracy: 0.5599
# Epoch 44/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.7811 - accuracy: 0.5837 - val_loss: 0.8410 - val_accuracy: 0.5625
# Epoch 45/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.7689 - accuracy: 0.5887 - val_loss: 0.8362 - val_accuracy: 0.5597
# Epoch 46/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.7740 - accuracy: 0.5833 - val_loss: 0.8599 - val_accuracy: 0.5407
# Epoch 47/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 0.7680 - accuracy: 0.5955 - val_loss: 0.8570 - val_accuracy: 0.5579
# Epoch 48/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 0.7691 - accuracy: 0.5977 - val_loss: 0.8090 - val_accuracy: 0.5655
# Epoch 49/80
# 1885/1885 [==============================] - 12s 6ms/step - loss: 0.7709 - accuracy: 0.5888 - val_loss: 0.8078 - val_accuracy: 0.5618
# Epoch 50/80
# 1885/1885 [==============================] - 21s 11ms/step - loss: 0.7619 - accuracy: 0.5900 - val_loss: 0.9654 - val_accuracy: 0.5433
# Epoch 51/80
# 1885/1885 [==============================] - 16s 9ms/step - loss: 0.7650 - accuracy: 0.5876 - val_loss: 0.9263 - val_accuracy: 0.5508
# Epoch 52/80
# 1885/1885 [==============================] - 16s 8ms/step - loss: 0.7610 - accuracy: 0.5889 - val_loss: 0.8307 - val_accuracy: 0.5543
# Epoch 53/80
# 1885/1885 [==============================] - 16s 9ms/step - loss: 0.7614 - accuracy: 0.5882 - val_loss: 0.8438 - val_accuracy: 0.5599
# Epoch 54/80
# 1885/1885 [==============================] - 17s 9ms/step - loss: 0.7585 - accuracy: 0.5977 - val_loss: 0.8136 - val_accuracy: 0.5653
# Epoch 55/80
# 1885/1885 [==============================] - 19s 10ms/step - loss: 0.7544 - accuracy: 0.5967 - val_loss: 0.8321 - val_accuracy: 0.5623
# Epoch 56/80
# 1885/1885 [==============================] - 19s 10ms/step - loss: 0.7581 - accuracy: 0.5952 - val_loss: 0.8444 - val_accuracy: 0.5651
# Epoch 57/80
# 1885/1885 [==============================] - 17s 9ms/step - loss: 0.7522 - accuracy: 0.5954 - val_loss: 0.8314 - val_accuracy: 0.5534
# Epoch 58/80
# 1885/1885 [==============================] - 19s 10ms/step - loss: 0.7601 - accuracy: 0.5909 - val_loss: 0.8261 - val_accuracy: 0.5644
# Epoch 59/80
# 1885/1885 [==============================] - 17s 9ms/step - loss: 0.7538 - accuracy: 0.5967 - val_loss: 0.7999 - val_accuracy: 0.5644
# Epoch 60/80
# 1885/1885 [==============================] - 15s 8ms/step - loss: 0.7557 - accuracy: 0.5929 - val_loss: 0.8224 - val_accuracy: 0.5659
# Epoch 61/80
# 1885/1885 [==============================] - 15s 8ms/step - loss: 0.7527 - accuracy: 0.5929 - val_loss: 0.8067 - val_accuracy: 0.5582
# Epoch 62/80
# 1885/1885 [==============================] - 14s 8ms/step - loss: 0.7551 - accuracy: 0.5956 - val_loss: 0.8084 - val_accuracy: 0.5646
# Epoch 63/80
# 1885/1885 [==============================] - 13s 7ms/step - loss: 0.7490 - accuracy: 0.5969 - val_loss: 0.8403 - val_accuracy: 0.5614
# Epoch 64/80
# 1885/1885 [==============================] - 13s 7ms/step - loss: 0.7576 - accuracy: 0.5941 - val_loss: 0.8169 - val_accuracy: 0.5676
# Epoch 65/80
# 1885/1885 [==============================] - 13s 7ms/step - loss: 0.7515 - accuracy: 0.5941 - val_loss: 0.8172 - val_accuracy: 0.5642
# Epoch 66/80
# 1885/1885 [==============================] - 12s 7ms/step - loss: 0.7516 - accuracy: 0.5929 - val_loss: 0.8785 - val_accuracy: 0.5584
# Epoch 67/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 0.7503 - accuracy: 0.5966 - val_loss: 0.8015 - val_accuracy: 0.5640
# Epoch 68/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 0.7479 - accuracy: 0.5967 - val_loss: 0.7934 - val_accuracy: 0.5625
# Epoch 69/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 0.7416 - accuracy: 0.6059 - val_loss: 0.7929 - val_accuracy: 0.5679
# Epoch 70/80
# 1885/1885 [==============================] - 9s 5ms/step - loss: 0.7432 - accuracy: 0.5910 - val_loss: 0.8102 - val_accuracy: 0.5642
# Epoch 71/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.7477 - accuracy: 0.5964 - val_loss: 0.7923 - val_accuracy: 0.5646
# Epoch 72/80
# 1885/1885 [==============================] - 8s 4ms/step - loss: 0.7451 - accuracy: 0.5952 - val_loss: 0.8134 - val_accuracy: 0.5599
# Epoch 73/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.7458 - accuracy: 0.5954 - val_loss: 0.9568 - val_accuracy: 0.5351
# Epoch 74/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 0.7445 - accuracy: 0.5963 - val_loss: 0.8169 - val_accuracy: 0.5689
# Epoch 75/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 0.7471 - accuracy: 0.5950 - val_loss: 0.7944 - val_accuracy: 0.5674
# Epoch 76/80
# 1885/1885 [==============================] - 11s 6ms/step - loss: 0.7415 - accuracy: 0.5918 - val_loss: 0.8042 - val_accuracy: 0.5623
# Epoch 77/80
# 1885/1885 [==============================] - 10s 5ms/step - loss: 0.7428 - accuracy: 0.5947 - val_loss: 0.7911 - val_accuracy: 0.5657
# Epoch 78/80
# 1885/1885 [==============================] - 8s 4ms/step - loss: 0.7380 - accuracy: 0.6017 - val_loss: 0.8033 - val_accuracy: 0.5709
# Epoch 79/80
# 1885/1885 [==============================] - 8s 4ms/step - loss: 0.7376 - accuracy: 0.6015 - val_loss: 0.7964 - val_accuracy: 0.5605
# Epoch 80/80
# 1885/1885 [==============================] - 8s 4ms/step - loss: 0.7380 - accuracy: 0.6021 - val_loss: 0.7910 - val_accuracy: 0.5646
# Validation Accuracy: 0.566299319267273
# Validation Loss: 0.7887901663780212
# Test Accuracy: 0.5811922550201416
# Test Loss: 0.7722710371017456
# Average Validation Accuracy: 0.5682545304298401
# Average Validation Loss: 0.7895458340644836
# Average Test Accuracy: 0.5749494731426239

# %%
# Select the final model based on the average test accuracy across all folds
best_model_index = test_accuracy.index(max(test_accuracy))
best_model = models[best_model_index]
best_model_history = hist[best_model_index]
best_model_train_acc = train_accuracy[best_model_index]
best_model_train_loss = train_loss[best_model_index]
best_model_val_acc = val_accuracy[best_model_index]
best_model_val_loss = val_loss[best_model_index]

# summarize history for accuracy  
plt.subplot(211)  
plt.plot(best_model_history.history['accuracy'])  
plt.plot(best_model_history.history['val_accuracy'])  
plt.title('model accuracy')  
plt.ylabel('accuracy')  
plt.xlabel('epoch')  
plt.legend(['train', 'test'], loc='lower right')  

# summarize history for loss
plt.subplot(212)  
plt.plot(best_model_history.history['loss'])  
plt.plot(best_model_history.history['val_loss'])  
plt.title('model loss')  
plt.ylabel('loss')  
plt.xlabel('epoch')  
plt.legend(['train', 'test'], loc='upper right')  
plt.subplots_adjust(hspace=0.7)

plt.show() 

print("Final Test Accuracy:", test_accuracy[best_model_index])
# Out:
# Final Test Accuracy: 0.5811922550201416

# %%
# Evaluate the best model on the test data
y_pred = best_model.predict(X_test)

# np.argmax() is used to convert the one-hot encoded predictions and test labels to class labels.
y_pred_label=np.argmax(y_pred, axis = 1)


rounded_ytestenc=np.argmax(y_test_enc, axis=1)

# Print the classification report
print("Classification report:\n", classification_report(rounded_ytestenc, y_pred_label))

cm = confusion_matrix(rounded_ytestenc, y_pred_label)
draw_confusion_matrix(cm)
print("Confusion matrix:\n", cm)

#Printing the accuracy
print("Accuracy:",accuracy(cm))
# Out:
# 433/433 [==============================] - 3s 4ms/step
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.55      0.57      0.56      1909
#            1       0.58      0.47      0.52      4575
#            2       0.77      0.87      0.82      2787
#            3       0.37      0.45      0.41      2469
#            4       0.61      0.61      0.61      2066
#            5       0.81      0.76      0.78        50
#
#     accuracy                           0.58     13856
#    macro avg       0.62      0.62      0.62     13856
# weighted avg       0.58      0.58      0.58     13856
# Confusion matrix:
#  [[1080  167   67  529   66    0]
#  [ 502 2129  516 1097  322    9]
#  [  19  247 2426   94    1    0]
#  [ 149  726   75 1114  405    0]
#  [ 219  371   69  141 1266    0]
#  [   4    8    0    0    0   38]]
# Accuracy: 0.5811922632794457

# %%
target_names = np.array(['cold', 'drought', 'heat', 'salt', 'stress', 'submergence'])

n_classes = len(np.unique(Y)) # 6

# predict probabilities for each class
y_score = best_model.predict(X_test)


# store the fpr, tpr, and roc_auc for all averaging strategies
fpr, tpr, roc_auc = dict(), dict(), dict()

# ROC curve using micro-averaged OvR
# Compute micro-average ROC curve and ROC area
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_enc[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test_enc.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Compute macro-average ROC curve and ROC area
# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at these points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

#Plot all OvR ROC curves together
fig, ax = plt.subplots(figsize=(8, 6))

colors = cycle(["aqua", "darkorange", "cornflowerblue", "green", "purple", "red"])
for class_id, color, target_name in zip(range(n_classes), colors, target_names):
    plt.plot(
        fpr[class_id],
        tpr[class_id],
        color=color,
        lw=2,
        label=f"{target_name} (AUC = {roc_auc[class_id]:.3f})",
    )

plt.plot(
    fpr["micro"],
    tpr["micro"],
    label=f"micro-average (AUC = {roc_auc['micro']:.3f})",
    color="deeppink",
    linestyle=":",
    linewidth=4,
)

plt.plot(
    fpr["macro"],
    tpr["macro"],
    label=f"macro-average (AUC = {roc_auc['macro']:.3f})",
    color="navy",
    linestyle=":",
    linewidth=4,
)



plt.plot([0, 1], [0, 1], "k--", label="chance level (AUC = 0.5)")
plt.axis("square")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("One-vs-Rest multiclass ROC")
plt.legend(loc="lower right")
plt.show()
# Out:
# 433/433 [==============================] - 2s 4ms/step

# %%
import pickle

filepath = 'CNN_roc.pkl'
data = {'CNN_fpr_macro': fpr['macro'],
        'CNN_tpr_macro': tpr['macro'],
        'CNN_auc_macro': roc_auc['macro']}

with open(filepath,'wb') as f:
    pickle.dump(data,f)

# %%
#created for the result.csv
dataTrait1 = df.drop(columns=["Class"]) #create for csv output
X1 = dataTrait1.drop(["Trait"], axis=1) #create for csv output

# split into train and test sets
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, Y, test_size=0.33, random_state=1)

# extract OsID from test data 
OsID_test = X_test1['OsID'].values

trait_names = (['cold', 'drought', 'heat', 'salt', 'stress', 'submergence'])

# map class labels to target names
true_class = [trait_names[i] for i in rounded_ytestenc]
predicted_class = [trait_names[i] for i in y_pred_label]

# create dataframe with OsID, true class, predicted class, and true/false columns
results = pd.DataFrame({
    'OsID': OsID_test,
    'True Class': true_class,
    'Predicted Class': predicted_class,
    'True/False': [x == y for x, y in zip(true_class, predicted_class)]})


# display dataframe
print(results.head())

# save results_df to a CSV file
results.to_csv('CNN_trait classification.csv', index=False)
# Out:
#            OsID True Class Predicted Class  True/False
# 0  Os09g0522200       cold            salt       False
# 1  Os11g0592200    drought         drought        True
# 2  Os01g0699100     stress          stress        True
# 3  Os02g0126400    drought         drought        True
# 4  Os03g0669100    drought          stress       False
